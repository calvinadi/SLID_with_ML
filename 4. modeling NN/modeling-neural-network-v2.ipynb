# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import joblib
from sklearn.model_selection import KFold

# %%
df = pd.read_csv(r"/kaggle/input/feature-common-language/audio_features_partial.csv")
df.head()
# Out:
#    chroma_stft       rms  spectral_centroid  spectral_bandwidth  \
# 0     0.712224  0.055740        2989.050985         2193.800068
# 1     0.598403  0.074004        2372.315827         2065.561020
# 2     0.756316  0.046051        3274.178654         2196.474265
# 3     0.588983  0.061376        1948.418292         2049.242741
# 4     0.647222  0.069638        1705.618989         1824.714129
#
#    spectral_rolloff  zero_crossing_rate     mfcc_1     mfcc_2     mfcc_3  \
# 0       5666.294643            0.275144 -202.32579  27.614292   4.094784
# 1       4795.649510            0.178041 -137.41476  59.931843   5.077963
# 2       5870.572917            0.353054 -233.02031  22.691550  10.057923
# 3       4186.921296            0.137682 -199.04490  80.806870  31.451380
# 4       3730.709877            0.095540 -325.47556  92.373820  17.725632
#
#       mfcc_4  ...    mfcc_13   mfcc_14    mfcc_15   mfcc_16   mfcc_17  \
# 0   5.301181  ...   4.752774 -0.985637  -6.752584 -4.679379 -5.478848
# 1  -5.712012  ... -12.469353 -2.134825 -10.989368 -1.460541 -4.485021
# 2   3.829097  ...  -1.657243 -5.409642  -4.017134 -6.744406 -1.697630
# 3  -1.297673  ...  -4.202263  0.065943  -9.312079 -7.164060 -3.082040
# 4  31.867613  ...   3.169903  4.538502  -1.073114 -1.204524 -0.108214
#
#     mfcc_18   mfcc_19   mfcc_20   label  \
# 0 -0.866508 -1.919669 -0.634521  Arabic
# 1 -0.408789 -8.211143 -5.170048  Arabic
# 2 -0.387302  0.829549  1.292110  Arabic
# 3 -8.046175 -3.083879 -2.018449  Arabic
# 4 -4.803460 -2.882802 -1.455632  Arabic
#
#                                            file_path
# 0  /kaggle/input/preprocess-common-language/proce...
# 1  /kaggle/input/preprocess-common-language/proce...
# 2  /kaggle/input/preprocess-common-language/proce...
# 3  /kaggle/input/preprocess-common-language/proce...
# 4  /kaggle/input/preprocess-common-language/proce...
#
# [5 rows x 28 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Fit LabelEncoder with your actual labels
label_encoder.fit(df['label'])

# Transform actual labels to numeric labels
df['numeric_labels'] = label_encoder.transform(df['label'])

# %%
X = df.drop(columns=['label','numeric_labels','file_path'])
y = df['numeric_labels']

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(sampling_strategy='auto', random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# %%
from collections import Counter

# Jumlah kelas sebelum SMOTE
print("Jumlah kelas sebelum SMOTE:")
print(Counter(y))

# Jumlah kelas setelah SMOTE
print("\nJumlah kelas setelah SMOTE:")
print(Counter(y_resampled))
# Out:
# Jumlah kelas sebelum SMOTE:
# Counter({2: 3570, 39: 3177, 19: 3012, 6: 3003, 27: 2955, 41: 2784, 24: 2766, 0: 2751, 20: 2733, 37: 2691, 10: 2550, 33: 2547, 18: 2520, 21: 2484, 42: 2472, 8: 2442, 40: 2367, 26: 2331, 30: 2283, 28: 2277, 23: 2268, 32: 2238, 7: 2202, 31: 2196, 43: 2181, 15: 2073, 44: 2073, 5: 2016, 34: 1977, 9: 1962, 25: 1947, 12: 1932, 1: 1914, 16: 1890, 29: 1884, 14: 1863, 3: 1830, 17: 1830, 4: 1797, 11: 1773, 35: 1758, 36: 1752, 38: 1737, 22: 1695, 13: 1623})
#
# Jumlah kelas setelah SMOTE:
# Counter({0: 3570, 4: 3570, 9: 3570, 27: 3570, 18: 3570, 24: 3570, 23: 3570, 13: 3570, 20: 3570, 11: 3570, 16: 3570, 40: 3570, 28: 3570, 15: 3570, 21: 3570, 8: 3570, 31: 3570, 29: 3570, 5: 3570, 7: 3570, 41: 3570, 44: 3570, 3: 3570, 2: 3570, 14: 3570, 43: 3570, 36: 3570, 26: 3570, 34: 3570, 12: 3570, 37: 3570, 35: 3570, 42: 3570, 33: 3570, 17: 3570, 25: 3570, 6: 3570, 30: 3570, 39: 3570, 22: 3570, 10: 3570, 1: 3570, 19: 3570, 32: 3570, 38: 3570})

# %%
### split data 80% 20%

X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled,
                                                    test_size=0.2, random_state=42,
                                                    stratify=y_resampled)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input, BatchNormalization
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.regularizers import l1_l2
# Out:
# 2024-07-03 14:55:09.533252: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-03 14:55:09.533299: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-03 14:55:09.534797: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
num_classes = len(label_encoder.classes_)
input_dim=X_train.shape[1]

model = Sequential()
model.add(Input(shape=(input_dim,)))
model.add(Dense(256, activation='relu', kernel_regularizer=l1_l2(l1=0.01, l2=0.01)))
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu', kernel_regularizer=l1_l2(l1=0.01, l2=0.01)))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu', kernel_regularizer=l1_l2(l1=0.01, l2=0.01)))   
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 256)            │         6,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 45)             │         2,925 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 50,989 (199.18 KB)
#  Trainable params: 50,989 (199.18 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import datetime


# Membuat callback EarlyStopping
early_stopping = EarlyStopping(
    monitor='val_loss', 
    patience=10,         
    restore_best_weights=True, 
    verbose=1
)

reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=5, min_lr=0.000001, verbose=1)

model_checkpoint = ModelCheckpoint('best_model.keras', 
                                   save_best_only=True, 
                                   monitor='val_accuracy',
                                   mode='max', 
                                   verbose=1)

log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

history = model.fit(
    X_train, y_train,
    validation_data=(X_test,y_test),
    epochs=200,
    batch_size=32,
    callbacks=[early_stopping, reduce_lr, model_checkpoint, tensorboard_callback],
    verbose=1
)
# Out:
# Epoch 1/200
#   56/4017 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.0265 - loss: 277.3068
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1720018519.927600    3995 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0218 - loss: 26.3240
# Epoch 1: val_accuracy improved from -inf to 0.02222, saving model to best_model.keras
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step - accuracy: 0.0218 - loss: 26.3207 - val_accuracy: 0.0222 - val_loss: 5.3195 - learning_rate: 0.0010
# Epoch 2/200
# 4012/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0230 - loss: 4.5173
# Epoch 2: val_accuracy did not improve from 0.02222
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.0230 - loss: 4.5167 - val_accuracy: 0.0222 - val_loss: 3.8548 - learning_rate: 0.0010
# Epoch 3/200
# 4005/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0211 - loss: 3.8552
# Epoch 3: val_accuracy did not improve from 0.02222
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.0211 - loss: 3.8552 - val_accuracy: 0.0222 - val_loss: 3.8597 - learning_rate: 0.0010
# Epoch 4/200
# 4011/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0203 - loss: 3.8605
# Epoch 4: val_accuracy did not improve from 0.02222
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.0203 - loss: 3.8605 - val_accuracy: 0.0222 - val_loss: 3.8609 - learning_rate: 0.0010
# Epoch 5/200
# 4006/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0226 - loss: 3.8611
# Epoch 5: val_accuracy did not improve from 0.02222
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.0226 - loss: 3.8611 - val_accuracy: 0.0222 - val_loss: 3.8612 - learning_rate: 0.0010
# Epoch 6/200
# 4000/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0216 - loss: 3.8612
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 6: val_accuracy did not improve from 0.02222
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.0216 - loss: 3.8612 - val_accuracy: 0.0222 - val_loss: 3.8610 - learning_rate: 0.0010
# Epoch 7/200
# 3996/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0222 - loss: 3.8131
# Epoch 7: val_accuracy did not improve from 0.02222
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.0222 - loss: 3.8131 - val_accuracy: 0.0222 - val_loss: 3.8117 - learning_rate: 1.0000e-04
# Epoch 8/200
# 3997/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0218 - loss: 3.8121
# Epoch 8: val_accuracy did not improve from 0.02222
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.0218 - loss: 3.8121 - val_accuracy: 0.0222 - val_loss: 3.8115 - learning_rate: 1.0000e-04
# Epoch 9/200
# 4013/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0221 - loss: 3.8117
# Epoch 9: val_accuracy did not improve from 0.02222
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.0221 - loss: 3.8117 - val_accuracy: 0.0222 - val_loss: 3.8118 - learning_rate: 1.0000e-04
# Epoch 10/200
# 4013/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0210 - loss: 3.8117
# Epoch 10: val_accuracy did not improve from 0.02222
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.0210 - loss: 3.8117 - val_accuracy: 0.0222 - val_loss: 3.8130 - learning_rate: 1.0000e-04
# Epoch 11/200
# 3995/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0215 - loss: 3.8120
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 11: val_accuracy did not improve from 0.02222
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.0215 - loss: 3.8120 - val_accuracy: 0.0222 - val_loss: 3.8126 - learning_rate: 1.0000e-04
# Epoch 12/200
# 4004/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0216 - loss: 3.8074
# Epoch 12: val_accuracy did not improve from 0.02222
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.0216 - loss: 3.8074 - val_accuracy: 0.0222 - val_loss: 3.8072 - learning_rate: 1.0000e-05
# Epoch 13/200
# 4009/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0215 - loss: 3.8073
# Epoch 13: val_accuracy did not improve from 0.02222
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.0215 - loss: 3.8073 - val_accuracy: 0.0222 - val_loss: 3.8073 - learning_rate: 1.0000e-05
# Epoch 14/200
# 4010/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0212 - loss: 3.8073
# Epoch 14: val_accuracy did not improve from 0.02222
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.0212 - loss: 3.8073 - val_accuracy: 0.0222 - val_loss: 3.8073 - learning_rate: 1.0000e-05
# Epoch 15/200
# 4000/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0218 - loss: 3.8073
# Epoch 15: val_accuracy did not improve from 0.02222
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.0218 - loss: 3.8073 - val_accuracy: 0.0222 - val_loss: 3.8072 - learning_rate: 1.0000e-05
# Epoch 16/200
# 3999/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0226 - loss: 3.8073
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 16: val_accuracy did not improve from 0.02222
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.0226 - loss: 3.8073 - val_accuracy: 0.0222 - val_loss: 3.8073 - learning_rate: 1.0000e-05
# Epoch 17/200
# 4011/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0220 - loss: 3.8067
# Epoch 17: val_accuracy did not improve from 0.02222
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.0220 - loss: 3.8067 - val_accuracy: 0.0222 - val_loss: 3.8067 - learning_rate: 1.0000e-06
# Epoch 18/200
# 4003/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0222 - loss: 3.8067
# Epoch 18: val_accuracy did not improve from 0.02222
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.0222 - loss: 3.8067 - val_accuracy: 0.0222 - val_loss: 3.8067 - learning_rate: 1.0000e-06
# Epoch 19/200
# 3994/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0222 - loss: 3.8067
# Epoch 19: val_accuracy did not improve from 0.02222
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.0222 - loss: 3.8067 - val_accuracy: 0.0222 - val_loss: 3.8067 - learning_rate: 1.0000e-06
# Epoch 20/200
# 4010/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0219 - loss: 3.8067
# Epoch 20: val_accuracy did not improve from 0.02222
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.0219 - loss: 3.8067 - val_accuracy: 0.0222 - val_loss: 3.8067 - learning_rate: 1.0000e-06
# Epoch 21/200
# 4015/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0222 - loss: 3.8067
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 21: val_accuracy did not improve from 0.02222
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.0222 - loss: 3.8067 - val_accuracy: 0.0222 - val_loss: 3.8067 - learning_rate: 1.0000e-06
# Epoch 22/200
# 3994/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0215 - loss: 3.8067
# Epoch 22: val_accuracy did not improve from 0.02222
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.0215 - loss: 3.8067 - val_accuracy: 0.0222 - val_loss: 3.8067 - learning_rate: 1.0000e-06
# Epoch 23/200
# 4016/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0222 - loss: 3.8067
# Epoch 23: val_accuracy did not improve from 0.02222
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.0222 - loss: 3.8067 - val_accuracy: 0.0222 - val_loss: 3.8067 - learning_rate: 1.0000e-06
# Epoch 24/200
# 3993/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0222 - loss: 3.8067
# Epoch 24: val_accuracy did not improve from 0.02222
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.0222 - loss: 3.8067 - val_accuracy: 0.0222 - val_loss: 3.8067 - learning_rate: 1.0000e-06
# Epoch 25/200
# 3994/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0217 - loss: 3.8067
# Epoch 25: val_accuracy did not improve from 0.02222
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.0217 - loss: 3.8067 - val_accuracy: 0.0222 - val_loss: 3.8067 - learning_rate: 1.0000e-06
# Epoch 26/200
# 3996/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0222 - loss: 3.8067
# Epoch 26: val_accuracy did not improve from 0.02222
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.0222 - loss: 3.8067 - val_accuracy: 0.0222 - val_loss: 3.8067 - learning_rate: 1.0000e-06
# Epoch 27/200
# 3998/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0222 - loss: 3.8067
# Epoch 27: val_accuracy did not improve from 0.02222
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.0222 - loss: 3.8067 - val_accuracy: 0.0222 - val_loss: 3.8067 - learning_rate: 1.0000e-06
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_accuracy:.5f}")
# Out:
# Test accuracy: 0.02222

# %%
# Learning Curve
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], marker='o')
plt.plot(history.history['val_accuracy'], marker='o')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='lower right')
plt.show()
