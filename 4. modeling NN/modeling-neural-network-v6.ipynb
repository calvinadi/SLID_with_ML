# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import joblib
from sklearn.model_selection import KFold

# %%
df = pd.read_csv(r"/kaggle/input/feature-common-language/audio_features_partial.csv")
df.head()
# Out:
#    chroma_stft       rms  spectral_centroid  spectral_bandwidth  \
# 0     0.712224  0.055740        2989.050985         2193.800068
# 1     0.598403  0.074004        2372.315827         2065.561020
# 2     0.756316  0.046051        3274.178654         2196.474265
# 3     0.588983  0.061376        1948.418292         2049.242741
# 4     0.647222  0.069638        1705.618989         1824.714129
#
#    spectral_rolloff  zero_crossing_rate     mfcc_1     mfcc_2     mfcc_3  \
# 0       5666.294643            0.275144 -202.32579  27.614292   4.094784
# 1       4795.649510            0.178041 -137.41476  59.931843   5.077963
# 2       5870.572917            0.353054 -233.02031  22.691550  10.057923
# 3       4186.921296            0.137682 -199.04490  80.806870  31.451380
# 4       3730.709877            0.095540 -325.47556  92.373820  17.725632
#
#       mfcc_4  ...    mfcc_13   mfcc_14    mfcc_15   mfcc_16   mfcc_17  \
# 0   5.301181  ...   4.752774 -0.985637  -6.752584 -4.679379 -5.478848
# 1  -5.712012  ... -12.469353 -2.134825 -10.989368 -1.460541 -4.485021
# 2   3.829097  ...  -1.657243 -5.409642  -4.017134 -6.744406 -1.697630
# 3  -1.297673  ...  -4.202263  0.065943  -9.312079 -7.164060 -3.082040
# 4  31.867613  ...   3.169903  4.538502  -1.073114 -1.204524 -0.108214
#
#     mfcc_18   mfcc_19   mfcc_20   label  \
# 0 -0.866508 -1.919669 -0.634521  Arabic
# 1 -0.408789 -8.211143 -5.170048  Arabic
# 2 -0.387302  0.829549  1.292110  Arabic
# 3 -8.046175 -3.083879 -2.018449  Arabic
# 4 -4.803460 -2.882802 -1.455632  Arabic
#
#                                            file_path
# 0  /kaggle/input/preprocess-common-language/proce...
# 1  /kaggle/input/preprocess-common-language/proce...
# 2  /kaggle/input/preprocess-common-language/proce...
# 3  /kaggle/input/preprocess-common-language/proce...
# 4  /kaggle/input/preprocess-common-language/proce...
#
# [5 rows x 28 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Fit LabelEncoder with your actual labels
label_encoder.fit(df['label'])

# Transform actual labels to numeric labels
df['numeric_labels'] = label_encoder.transform(df['label'])

# %%
X = df.drop(columns=['label','numeric_labels','file_path'])
y = df['numeric_labels']

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(sampling_strategy='auto', random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# %%
from collections import Counter

# Jumlah kelas sebelum SMOTE
print("Jumlah kelas sebelum SMOTE:")
print(Counter(y))

# Jumlah kelas setelah SMOTE
print("\nJumlah kelas setelah SMOTE:")
print(Counter(y_resampled))
# Out:
# Jumlah kelas sebelum SMOTE:
# Counter({2: 3570, 39: 3177, 19: 3012, 6: 3003, 27: 2955, 41: 2784, 24: 2766, 0: 2751, 20: 2733, 37: 2691, 10: 2550, 33: 2547, 18: 2520, 21: 2484, 42: 2472, 8: 2442, 40: 2367, 26: 2331, 30: 2283, 28: 2277, 23: 2268, 32: 2238, 7: 2202, 31: 2196, 43: 2181, 15: 2073, 44: 2073, 5: 2016, 34: 1977, 9: 1962, 25: 1947, 12: 1932, 1: 1914, 16: 1890, 29: 1884, 14: 1863, 3: 1830, 17: 1830, 4: 1797, 11: 1773, 35: 1758, 36: 1752, 38: 1737, 22: 1695, 13: 1623})
#
# Jumlah kelas setelah SMOTE:
# Counter({0: 3570, 4: 3570, 9: 3570, 27: 3570, 18: 3570, 24: 3570, 23: 3570, 13: 3570, 20: 3570, 11: 3570, 16: 3570, 40: 3570, 28: 3570, 15: 3570, 21: 3570, 8: 3570, 31: 3570, 29: 3570, 5: 3570, 7: 3570, 41: 3570, 44: 3570, 3: 3570, 2: 3570, 14: 3570, 43: 3570, 36: 3570, 26: 3570, 34: 3570, 12: 3570, 37: 3570, 35: 3570, 42: 3570, 33: 3570, 17: 3570, 25: 3570, 6: 3570, 30: 3570, 39: 3570, 22: 3570, 10: 3570, 1: 3570, 19: 3570, 32: 3570, 38: 3570})

# %%
### split data 80% 20%

X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled,
                                                    test_size=0.2, random_state=42,
                                                    stratify=y_resampled)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.regularizers import l1_l2
# Out:
# 2024-07-04 10:55:48.999207: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-04 10:55:48.999332: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-04 10:55:49.089068: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

num_classes = len(label_encoder.classes_)
input_dim = X_train.shape[1]

# Reshape input untuk LSTM (batch_size, timesteps, features)
# Kita akan menganggap setiap fitur sebagai satu timestep
X_train_reshaped = X_train.values.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test_reshaped = X_test.values.reshape(X_test.shape[0], X_test.shape[1], 1)

# Model architecture
inputs = Input(shape=(input_dim, 1))

x = Bidirectional(LSTM(256, return_sequences=True, kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4)))(inputs)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)

x = Bidirectional(LSTM(128, return_sequences=True, kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4)))(x)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)

x = Bidirectional(LSTM(64, return_sequences=True, kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4)))(x)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)

# Attention layer
attention = Attention()([x, x])
x = Flatten()(attention)

x = Dense(128, activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4))(x)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)

outputs = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=inputs, outputs=outputs)

model.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import datetime


# Membuat callback EarlyStopping
early_stopping = EarlyStopping(
    monitor='val_loss', 
    patience=10,         
    restore_best_weights=True, 
    verbose=1
)

reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=5, min_lr=0.000001, verbose=1)

model_checkpoint = ModelCheckpoint('best_model.keras', 
                                   save_best_only=True, 
                                   monitor='val_accuracy',
                                   mode='max', 
                                   verbose=1)

log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

history = model.fit(
    X_train, y_train,
    validation_data=(X_test,y_test),
    epochs=200,
    batch_size=64,
    callbacks=[early_stopping, reduce_lr, model_checkpoint, tensorboard_callback],
    verbose=1
)
# Out:
# Epoch 1/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.0815 - loss: 4.2779
# Epoch 1: val_accuracy improved from -inf to 0.19166, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 55s 23ms/step - accuracy: 0.0815 - loss: 4.2777 - val_accuracy: 0.1917 - val_loss: 3.5978 - learning_rate: 0.0010
# Epoch 2/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.2057 - loss: 3.5407
# Epoch 2: val_accuracy improved from 0.19166 to 0.26082, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.2057 - loss: 3.5406 - val_accuracy: 0.2608 - val_loss: 3.2795 - learning_rate: 0.0010
# Epoch 3/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.2509 - loss: 3.3414
# Epoch 3: val_accuracy improved from 0.26082 to 0.29885, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.2509 - loss: 3.3414 - val_accuracy: 0.2988 - val_loss: 3.1484 - learning_rate: 0.0010
# Epoch 4/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.2779 - loss: 3.2593
# Epoch 4: val_accuracy improved from 0.29885 to 0.31805, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.2779 - loss: 3.2593 - val_accuracy: 0.3181 - val_loss: 3.1009 - learning_rate: 0.0010
# Epoch 5/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.2958 - loss: 3.1983
# Epoch 5: val_accuracy improved from 0.31805 to 0.33788, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.2958 - loss: 3.1983 - val_accuracy: 0.3379 - val_loss: 3.0269 - learning_rate: 0.0010
# Epoch 6/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3090 - loss: 3.1661
# Epoch 6: val_accuracy improved from 0.33788 to 0.36004, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.3090 - loss: 3.1660 - val_accuracy: 0.3600 - val_loss: 2.9606 - learning_rate: 0.0010
# Epoch 7/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3230 - loss: 3.1115
# Epoch 7: val_accuracy improved from 0.36004 to 0.36832, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.3230 - loss: 3.1115 - val_accuracy: 0.3683 - val_loss: 2.9201 - learning_rate: 0.0010
# Epoch 8/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3220 - loss: 3.1589
# Epoch 8: val_accuracy improved from 0.36832 to 0.39045, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.3220 - loss: 3.1589 - val_accuracy: 0.3904 - val_loss: 2.8654 - learning_rate: 0.0010
# Epoch 9/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3437 - loss: 3.0367
# Epoch 9: val_accuracy improved from 0.39045 to 0.39514, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.3437 - loss: 3.0368 - val_accuracy: 0.3951 - val_loss: 2.8399 - learning_rate: 0.0010
# Epoch 10/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3515 - loss: 3.0034
# Epoch 10: val_accuracy improved from 0.39514 to 0.41478, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.3515 - loss: 3.0034 - val_accuracy: 0.4148 - val_loss: 2.7577 - learning_rate: 0.0010
# Epoch 11/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3638 - loss: 2.9648
# Epoch 11: val_accuracy did not improve from 0.41478
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.3637 - loss: 2.9648 - val_accuracy: 0.4128 - val_loss: 2.7841 - learning_rate: 0.0010
# Epoch 12/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3685 - loss: 2.9368
# Epoch 12: val_accuracy improved from 0.41478 to 0.42325, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.3685 - loss: 2.9368 - val_accuracy: 0.4232 - val_loss: 2.7359 - learning_rate: 0.0010
# Epoch 13/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3762 - loss: 2.9182
# Epoch 13: val_accuracy did not improve from 0.42325
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.3762 - loss: 2.9182 - val_accuracy: 0.4205 - val_loss: 2.7400 - learning_rate: 0.0010
# Epoch 14/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3790 - loss: 2.9020
# Epoch 14: val_accuracy improved from 0.42325 to 0.43974, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.3790 - loss: 2.9020 - val_accuracy: 0.4397 - val_loss: 2.6940 - learning_rate: 0.0010
# Epoch 15/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3876 - loss: 2.8789
# Epoch 15: val_accuracy improved from 0.43974 to 0.44024, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.3875 - loss: 2.8789 - val_accuracy: 0.4402 - val_loss: 2.6894 - learning_rate: 0.0010
# Epoch 16/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3941 - loss: 2.8568
# Epoch 16: val_accuracy improved from 0.44024 to 0.44466, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.3941 - loss: 2.8568 - val_accuracy: 0.4447 - val_loss: 2.6737 - learning_rate: 0.0010
# Epoch 17/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4014 - loss: 2.8284
# Epoch 17: val_accuracy improved from 0.44466 to 0.44890, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.4014 - loss: 2.8284 - val_accuracy: 0.4489 - val_loss: 2.6647 - learning_rate: 0.0010
# Epoch 18/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4028 - loss: 2.8278
# Epoch 18: val_accuracy improved from 0.44890 to 0.46682, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.4028 - loss: 2.8278 - val_accuracy: 0.4668 - val_loss: 2.6082 - learning_rate: 0.0010
# Epoch 19/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4092 - loss: 2.8012
# Epoch 19: val_accuracy improved from 0.46682 to 0.47249, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.4092 - loss: 2.8012 - val_accuracy: 0.4725 - val_loss: 2.5909 - learning_rate: 0.0010
# Epoch 20/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4158 - loss: 2.7771
# Epoch 20: val_accuracy improved from 0.47249 to 0.48030, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.4158 - loss: 2.7771 - val_accuracy: 0.4803 - val_loss: 2.5659 - learning_rate: 0.0010
# Epoch 21/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4231 - loss: 2.7561
# Epoch 21: val_accuracy improved from 0.48030 to 0.48973, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 82s 23ms/step - accuracy: 0.4231 - loss: 2.7562 - val_accuracy: 0.4897 - val_loss: 2.5455 - learning_rate: 0.0010
# Epoch 22/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4286 - loss: 2.7379
# Epoch 22: val_accuracy improved from 0.48973 to 0.49054, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.4286 - loss: 2.7380 - val_accuracy: 0.4905 - val_loss: 2.5212 - learning_rate: 0.0010
# Epoch 23/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4297 - loss: 2.7216
# Epoch 23: val_accuracy improved from 0.49054 to 0.49997, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.4297 - loss: 2.7217 - val_accuracy: 0.5000 - val_loss: 2.5149 - learning_rate: 0.0010
# Epoch 24/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4351 - loss: 2.7075
# Epoch 24: val_accuracy did not improve from 0.49997
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.4351 - loss: 2.7075 - val_accuracy: 0.4862 - val_loss: 2.5605 - learning_rate: 0.0010
# Epoch 25/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4386 - loss: 2.6963
# Epoch 25: val_accuracy did not improve from 0.49997
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.4386 - loss: 2.6963 - val_accuracy: 0.4881 - val_loss: 2.5354 - learning_rate: 0.0010
# Epoch 26/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4451 - loss: 2.6786
# Epoch 26: val_accuracy improved from 0.49997 to 0.50545, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.4451 - loss: 2.6786 - val_accuracy: 0.5054 - val_loss: 2.4906 - learning_rate: 0.0010
# Epoch 27/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4486 - loss: 2.6661
# Epoch 27: val_accuracy improved from 0.50545 to 0.51251, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.4486 - loss: 2.6662 - val_accuracy: 0.5125 - val_loss: 2.4557 - learning_rate: 0.0010
# Epoch 28/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4519 - loss: 2.6454
# Epoch 28: val_accuracy improved from 0.51251 to 0.51544, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.4519 - loss: 2.6454 - val_accuracy: 0.5154 - val_loss: 2.4640 - learning_rate: 0.0010
# Epoch 29/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4564 - loss: 2.6302
# Epoch 29: val_accuracy improved from 0.51544 to 0.52023, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.4564 - loss: 2.6303 - val_accuracy: 0.5202 - val_loss: 2.4431 - learning_rate: 0.0010
# Epoch 30/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4615 - loss: 2.6139
# Epoch 30: val_accuracy improved from 0.52023 to 0.52642, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.4615 - loss: 2.6139 - val_accuracy: 0.5264 - val_loss: 2.4243 - learning_rate: 0.0010
# Epoch 31/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4666 - loss: 2.6008
# Epoch 31: val_accuracy did not improve from 0.52642
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.4666 - loss: 2.6008 - val_accuracy: 0.5238 - val_loss: 2.4145 - learning_rate: 0.0010
# Epoch 32/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4670 - loss: 2.5857
# Epoch 32: val_accuracy improved from 0.52642 to 0.52739, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.4670 - loss: 2.5857 - val_accuracy: 0.5274 - val_loss: 2.4193 - learning_rate: 0.0010
# Epoch 33/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4750 - loss: 2.5786
# Epoch 33: val_accuracy did not improve from 0.52739
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.4750 - loss: 2.5786 - val_accuracy: 0.5258 - val_loss: 2.4178 - learning_rate: 0.0010
# Epoch 34/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4753 - loss: 2.5648
# Epoch 34: val_accuracy improved from 0.52739 to 0.53361, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.4753 - loss: 2.5648 - val_accuracy: 0.5336 - val_loss: 2.3959 - learning_rate: 0.0010
# Epoch 35/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4817 - loss: 2.5504
# Epoch 35: val_accuracy improved from 0.53361 to 0.54507, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.4817 - loss: 2.5504 - val_accuracy: 0.5451 - val_loss: 2.3599 - learning_rate: 0.0010
# Epoch 36/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4831 - loss: 2.5424
# Epoch 36: val_accuracy did not improve from 0.54507
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.4831 - loss: 2.5424 - val_accuracy: 0.5315 - val_loss: 2.4094 - learning_rate: 0.0010
# Epoch 37/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4911 - loss: 2.5139
# Epoch 37: val_accuracy improved from 0.54507 to 0.54743, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.4911 - loss: 2.5139 - val_accuracy: 0.5474 - val_loss: 2.3597 - learning_rate: 0.0010
# Epoch 38/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4915 - loss: 2.5099
# Epoch 38: val_accuracy improved from 0.54743 to 0.54905, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.4914 - loss: 2.5099 - val_accuracy: 0.5491 - val_loss: 2.3431 - learning_rate: 0.0010
# Epoch 39/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4977 - loss: 2.4809
# Epoch 39: val_accuracy improved from 0.54905 to 0.55571, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.4977 - loss: 2.4810 - val_accuracy: 0.5557 - val_loss: 2.3242 - learning_rate: 0.0010
# Epoch 40/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5009 - loss: 2.4780
# Epoch 40: val_accuracy did not improve from 0.55571
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.5009 - loss: 2.4780 - val_accuracy: 0.5535 - val_loss: 2.3250 - learning_rate: 0.0010
# Epoch 41/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5026 - loss: 2.4639
# Epoch 41: val_accuracy did not improve from 0.55571
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.5026 - loss: 2.4640 - val_accuracy: 0.5509 - val_loss: 2.3237 - learning_rate: 0.0010
# Epoch 42/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5054 - loss: 2.4529
# Epoch 42: val_accuracy improved from 0.55571 to 0.56138, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.5054 - loss: 2.4529 - val_accuracy: 0.5614 - val_loss: 2.3002 - learning_rate: 0.0010
# Epoch 43/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5103 - loss: 2.4403
# Epoch 43: val_accuracy did not improve from 0.56138
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.5103 - loss: 2.4403 - val_accuracy: 0.5604 - val_loss: 2.3093 - learning_rate: 0.0010
# Epoch 44/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5172 - loss: 2.4146
# Epoch 44: val_accuracy improved from 0.56138 to 0.56542, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.5172 - loss: 2.4146 - val_accuracy: 0.5654 - val_loss: 2.2939 - learning_rate: 0.0010
# Epoch 45/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5201 - loss: 2.4033
# Epoch 45: val_accuracy improved from 0.56542 to 0.56726, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 82s 23ms/step - accuracy: 0.5201 - loss: 2.4033 - val_accuracy: 0.5673 - val_loss: 2.2851 - learning_rate: 0.0010
# Epoch 46/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5177 - loss: 2.4170
# Epoch 46: val_accuracy did not improve from 0.56726
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.5177 - loss: 2.4170 - val_accuracy: 0.5637 - val_loss: 2.2873 - learning_rate: 0.0010
# Epoch 47/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5257 - loss: 2.3829
# Epoch 47: val_accuracy did not improve from 0.56726
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.5257 - loss: 2.3830 - val_accuracy: 0.5522 - val_loss: 2.3412 - learning_rate: 0.0010
# Epoch 48/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5288 - loss: 2.3720
# Epoch 48: val_accuracy did not improve from 0.56726
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.5288 - loss: 2.3720 - val_accuracy: 0.5632 - val_loss: 2.2855 - learning_rate: 0.0010
# Epoch 49/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5316 - loss: 2.3628
# Epoch 49: val_accuracy improved from 0.56726 to 0.57158, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.5316 - loss: 2.3629 - val_accuracy: 0.5716 - val_loss: 2.2653 - learning_rate: 0.0010
# Epoch 50/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5309 - loss: 2.3678
# Epoch 50: val_accuracy improved from 0.57158 to 0.57800, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.5309 - loss: 2.3678 - val_accuracy: 0.5780 - val_loss: 2.2374 - learning_rate: 0.0010
# Epoch 51/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5397 - loss: 2.3424
# Epoch 51: val_accuracy did not improve from 0.57800
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.5397 - loss: 2.3424 - val_accuracy: 0.5739 - val_loss: 2.2547 - learning_rate: 0.0010
# Epoch 52/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5439 - loss: 2.3184
# Epoch 52: val_accuracy improved from 0.57800 to 0.58083, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.5439 - loss: 2.3185 - val_accuracy: 0.5808 - val_loss: 2.2625 - learning_rate: 0.0010
# Epoch 53/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5417 - loss: 2.3267
# Epoch 53: val_accuracy improved from 0.58083 to 0.58214, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.5417 - loss: 2.3267 - val_accuracy: 0.5821 - val_loss: 2.2372 - learning_rate: 0.0010
# Epoch 54/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5484 - loss: 2.2985
# Epoch 54: val_accuracy improved from 0.58214 to 0.58220, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.5484 - loss: 2.2986 - val_accuracy: 0.5822 - val_loss: 2.2289 - learning_rate: 0.0010
# Epoch 55/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5509 - loss: 2.2921
# Epoch 55: val_accuracy did not improve from 0.58220
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.5509 - loss: 2.2921 - val_accuracy: 0.5796 - val_loss: 2.2335 - learning_rate: 0.0010
# Epoch 56/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5519 - loss: 2.2861
# Epoch 56: val_accuracy improved from 0.58220 to 0.58500, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.5519 - loss: 2.2861 - val_accuracy: 0.5850 - val_loss: 2.2255 - learning_rate: 0.0010
# Epoch 57/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5510 - loss: 2.2771
# Epoch 57: val_accuracy did not improve from 0.58500
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.5510 - loss: 2.2771 - val_accuracy: 0.5804 - val_loss: 2.2386 - learning_rate: 0.0010
# Epoch 58/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5568 - loss: 2.2626
# Epoch 58: val_accuracy improved from 0.58500 to 0.58845, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.5568 - loss: 2.2627 - val_accuracy: 0.5885 - val_loss: 2.2139 - learning_rate: 0.0010
# Epoch 59/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5599 - loss: 2.2558
# Epoch 59: val_accuracy did not improve from 0.58845
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.5599 - loss: 2.2558 - val_accuracy: 0.5843 - val_loss: 2.2179 - learning_rate: 0.0010
# Epoch 60/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5623 - loss: 2.2399
# Epoch 60: val_accuracy did not improve from 0.58845
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.5623 - loss: 2.2399 - val_accuracy: 0.5865 - val_loss: 2.2199 - learning_rate: 0.0010
# Epoch 61/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5661 - loss: 2.2305
# Epoch 61: val_accuracy improved from 0.58845 to 0.59399, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.5661 - loss: 2.2306 - val_accuracy: 0.5940 - val_loss: 2.1937 - learning_rate: 0.0010
# Epoch 62/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5714 - loss: 2.2126
# Epoch 62: val_accuracy improved from 0.59399 to 0.59773, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.5714 - loss: 2.2127 - val_accuracy: 0.5977 - val_loss: 2.1822 - learning_rate: 0.0010
# Epoch 63/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5754 - loss: 2.1934
# Epoch 63: val_accuracy did not improve from 0.59773
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.5754 - loss: 2.1934 - val_accuracy: 0.5973 - val_loss: 2.1876 - learning_rate: 0.0010
# Epoch 64/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5743 - loss: 2.1977
# Epoch 64: val_accuracy did not improve from 0.59773
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.5743 - loss: 2.1977 - val_accuracy: 0.5927 - val_loss: 2.1919 - learning_rate: 0.0010
# Epoch 65/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5765 - loss: 2.1954
# Epoch 65: val_accuracy did not improve from 0.59773
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.5765 - loss: 2.1954 - val_accuracy: 0.5968 - val_loss: 2.1979 - learning_rate: 0.0010
# Epoch 66/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5783 - loss: 2.1818
# Epoch 66: val_accuracy improved from 0.59773 to 0.59991, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.5783 - loss: 2.1818 - val_accuracy: 0.5999 - val_loss: 2.1819 - learning_rate: 0.0010
# Epoch 67/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5832 - loss: 2.1652
# Epoch 67: val_accuracy did not improve from 0.59991
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.5832 - loss: 2.1652 - val_accuracy: 0.5927 - val_loss: 2.2011 - learning_rate: 0.0010
# Epoch 68/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5859 - loss: 2.1555
# Epoch 68: val_accuracy improved from 0.59991 to 0.60314, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.5859 - loss: 2.1555 - val_accuracy: 0.6031 - val_loss: 2.1756 - learning_rate: 0.0010
# Epoch 69/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5852 - loss: 2.1527
# Epoch 69: val_accuracy did not improve from 0.60314
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.5852 - loss: 2.1528 - val_accuracy: 0.6011 - val_loss: 2.1732 - learning_rate: 0.0010
# Epoch 70/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5905 - loss: 2.1298
# Epoch 70: val_accuracy did not improve from 0.60314
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.5905 - loss: 2.1299 - val_accuracy: 0.6022 - val_loss: 2.1791 - learning_rate: 0.0010
# Epoch 71/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5916 - loss: 2.1347
# Epoch 71: val_accuracy did not improve from 0.60314
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.5916 - loss: 2.1348 - val_accuracy: 0.6009 - val_loss: 2.1731 - learning_rate: 0.0010
# Epoch 72/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5972 - loss: 2.1111
# Epoch 72: val_accuracy improved from 0.60314 to 0.60448, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.5972 - loss: 2.1111 - val_accuracy: 0.6045 - val_loss: 2.1553 - learning_rate: 0.0010
# Epoch 73/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6000 - loss: 2.1034
# Epoch 73: val_accuracy did not improve from 0.60448
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.6000 - loss: 2.1034 - val_accuracy: 0.5936 - val_loss: 2.2121 - learning_rate: 0.0010
# Epoch 74/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5973 - loss: 2.1157
# Epoch 74: val_accuracy did not improve from 0.60448
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.5973 - loss: 2.1158 - val_accuracy: 0.5951 - val_loss: 2.2008 - learning_rate: 0.0010
# Epoch 75/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5995 - loss: 2.0980
# Epoch 75: val_accuracy improved from 0.60448 to 0.60865, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.5994 - loss: 2.0981 - val_accuracy: 0.6087 - val_loss: 2.1536 - learning_rate: 0.0010
# Epoch 76/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6070 - loss: 2.0754
# Epoch 76: val_accuracy improved from 0.60865 to 0.61148, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.6070 - loss: 2.0754 - val_accuracy: 0.6115 - val_loss: 2.1473 - learning_rate: 0.0010
# Epoch 77/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6057 - loss: 2.0710
# Epoch 77: val_accuracy did not improve from 0.61148
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.6057 - loss: 2.0710 - val_accuracy: 0.6042 - val_loss: 2.1633 - learning_rate: 0.0010
# Epoch 78/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6071 - loss: 2.0600
# Epoch 78: val_accuracy did not improve from 0.61148
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.6071 - loss: 2.0601 - val_accuracy: 0.6027 - val_loss: 2.1813 - learning_rate: 0.0010
# Epoch 79/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6059 - loss: 2.0788
# Epoch 79: val_accuracy did not improve from 0.61148
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.6059 - loss: 2.0788 - val_accuracy: 0.6096 - val_loss: 2.1449 - learning_rate: 0.0010
# Epoch 80/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6131 - loss: 2.0468
# Epoch 80: val_accuracy did not improve from 0.61148
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.6130 - loss: 2.0469 - val_accuracy: 0.6075 - val_loss: 2.1614 - learning_rate: 0.0010
# Epoch 81/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6131 - loss: 2.0466
# Epoch 81: val_accuracy improved from 0.61148 to 0.61242, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.6131 - loss: 2.0467 - val_accuracy: 0.6124 - val_loss: 2.1465 - learning_rate: 0.0010
# Epoch 82/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6173 - loss: 2.0370
# Epoch 82: val_accuracy did not improve from 0.61242
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.6173 - loss: 2.0370 - val_accuracy: 0.6096 - val_loss: 2.1515 - learning_rate: 0.0010
# Epoch 83/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6186 - loss: 2.0311
# Epoch 83: val_accuracy did not improve from 0.61242
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 82s 23ms/step - accuracy: 0.6186 - loss: 2.0311 - val_accuracy: 0.6096 - val_loss: 2.1447 - learning_rate: 0.0010
# Epoch 84/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6227 - loss: 2.0091
# Epoch 84: val_accuracy did not improve from 0.61242
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.6227 - loss: 2.0091 - val_accuracy: 0.6061 - val_loss: 2.1629 - learning_rate: 0.0010
# Epoch 85/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6240 - loss: 2.0037
# Epoch 85: val_accuracy did not improve from 0.61242
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 46s 23ms/step - accuracy: 0.6240 - loss: 2.0037 - val_accuracy: 0.6096 - val_loss: 2.1465 - learning_rate: 0.0010
# Epoch 86/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6227 - loss: 2.0046
# Epoch 86: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 86: val_accuracy did not improve from 0.61242
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 47s 23ms/step - accuracy: 0.6227 - loss: 2.0046 - val_accuracy: 0.6096 - val_loss: 2.1600 - learning_rate: 0.0010
# Epoch 87/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6651 - loss: 1.8380
# Epoch 87: val_accuracy improved from 0.61242 to 0.65531, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.6651 - loss: 1.8379 - val_accuracy: 0.6553 - val_loss: 1.9535 - learning_rate: 1.0000e-04
# Epoch 88/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7076 - loss: 1.6528
# Epoch 88: val_accuracy improved from 0.65531 to 0.66608, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.7076 - loss: 1.6528 - val_accuracy: 0.6661 - val_loss: 1.8955 - learning_rate: 1.0000e-04
# Epoch 89/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7227 - loss: 1.5675
# Epoch 89: val_accuracy improved from 0.66608 to 0.67482, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.7227 - loss: 1.5675 - val_accuracy: 0.6748 - val_loss: 1.8490 - learning_rate: 1.0000e-04
# Epoch 90/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7366 - loss: 1.4989
# Epoch 90: val_accuracy improved from 0.67482 to 0.67803, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.7366 - loss: 1.4989 - val_accuracy: 0.6780 - val_loss: 1.8219 - learning_rate: 1.0000e-04
# Epoch 91/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7439 - loss: 1.4551
# Epoch 91: val_accuracy improved from 0.67803 to 0.68382, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.7439 - loss: 1.4551 - val_accuracy: 0.6838 - val_loss: 1.7843 - learning_rate: 1.0000e-04
# Epoch 92/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7527 - loss: 1.4040
# Epoch 92: val_accuracy improved from 0.68382 to 0.68755, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.7527 - loss: 1.4040 - val_accuracy: 0.6876 - val_loss: 1.7665 - learning_rate: 1.0000e-04
# Epoch 93/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7541 - loss: 1.3793
# Epoch 93: val_accuracy improved from 0.68755 to 0.69253, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.7541 - loss: 1.3793 - val_accuracy: 0.6925 - val_loss: 1.7424 - learning_rate: 1.0000e-04
# Epoch 94/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7595 - loss: 1.3391
# Epoch 94: val_accuracy improved from 0.69253 to 0.69449, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.7595 - loss: 1.3391 - val_accuracy: 0.6945 - val_loss: 1.7292 - learning_rate: 1.0000e-04
# Epoch 95/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7684 - loss: 1.3035
# Epoch 95: val_accuracy improved from 0.69449 to 0.69655, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.7684 - loss: 1.3035 - val_accuracy: 0.6965 - val_loss: 1.7146 - learning_rate: 1.0000e-04
# Epoch 96/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7697 - loss: 1.2831
# Epoch 96: val_accuracy improved from 0.69655 to 0.69707, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.7697 - loss: 1.2832 - val_accuracy: 0.6971 - val_loss: 1.7039 - learning_rate: 1.0000e-04
# Epoch 97/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7757 - loss: 1.2578
# Epoch 97: val_accuracy improved from 0.69707 to 0.69866, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 46s 23ms/step - accuracy: 0.7757 - loss: 1.2578 - val_accuracy: 0.6987 - val_loss: 1.6916 - learning_rate: 1.0000e-04
# Epoch 98/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7765 - loss: 1.2386
# Epoch 98: val_accuracy improved from 0.69866 to 0.70143, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.7765 - loss: 1.2387 - val_accuracy: 0.7014 - val_loss: 1.6747 - learning_rate: 1.0000e-04
# Epoch 99/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7803 - loss: 1.2136
# Epoch 99: val_accuracy improved from 0.70143 to 0.70349, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.7803 - loss: 1.2136 - val_accuracy: 0.7035 - val_loss: 1.6661 - learning_rate: 1.0000e-04
# Epoch 100/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7803 - loss: 1.2051
# Epoch 100: val_accuracy did not improve from 0.70349
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.7803 - loss: 1.2051 - val_accuracy: 0.7024 - val_loss: 1.6562 - learning_rate: 1.0000e-04
# Epoch 101/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7850 - loss: 1.1843
# Epoch 101: val_accuracy improved from 0.70349 to 0.70545, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.7850 - loss: 1.1843 - val_accuracy: 0.7054 - val_loss: 1.6456 - learning_rate: 1.0000e-04
# Epoch 102/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7830 - loss: 1.1769
# Epoch 102: val_accuracy improved from 0.70545 to 0.70619, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.7830 - loss: 1.1769 - val_accuracy: 0.7062 - val_loss: 1.6358 - learning_rate: 1.0000e-04
# Epoch 103/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7913 - loss: 1.1414
# Epoch 103: val_accuracy improved from 0.70619 to 0.70725, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.7912 - loss: 1.1414 - val_accuracy: 0.7073 - val_loss: 1.6325 - learning_rate: 1.0000e-04
# Epoch 104/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7908 - loss: 1.1398
# Epoch 104: val_accuracy improved from 0.70725 to 0.70906, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.7908 - loss: 1.1398 - val_accuracy: 0.7091 - val_loss: 1.6301 - learning_rate: 1.0000e-04
# Epoch 105/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7928 - loss: 1.1261
# Epoch 105: val_accuracy improved from 0.70906 to 0.71002, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.7928 - loss: 1.1261 - val_accuracy: 0.7100 - val_loss: 1.6170 - learning_rate: 1.0000e-04
# Epoch 106/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7942 - loss: 1.1106
# Epoch 106: val_accuracy improved from 0.71002 to 0.71008, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.7942 - loss: 1.1106 - val_accuracy: 0.7101 - val_loss: 1.6154 - learning_rate: 1.0000e-04
# Epoch 107/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7964 - loss: 1.0960
# Epoch 107: val_accuracy improved from 0.71008 to 0.71211, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.7964 - loss: 1.0960 - val_accuracy: 0.7121 - val_loss: 1.6095 - learning_rate: 1.0000e-04
# Epoch 108/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7994 - loss: 1.0800
# Epoch 108: val_accuracy improved from 0.71211 to 0.71273, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.7994 - loss: 1.0800 - val_accuracy: 0.7127 - val_loss: 1.6058 - learning_rate: 1.0000e-04
# Epoch 109/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8024 - loss: 1.0704
# Epoch 109: val_accuracy did not improve from 0.71273
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 47s 23ms/step - accuracy: 0.8024 - loss: 1.0704 - val_accuracy: 0.7124 - val_loss: 1.6036 - learning_rate: 1.0000e-04
# Epoch 110/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8034 - loss: 1.0585
# Epoch 110: val_accuracy improved from 0.71273 to 0.71488, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 46s 23ms/step - accuracy: 0.8034 - loss: 1.0585 - val_accuracy: 0.7149 - val_loss: 1.5862 - learning_rate: 1.0000e-04
# Epoch 111/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8048 - loss: 1.0493
# Epoch 111: val_accuracy did not improve from 0.71488
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8048 - loss: 1.0494 - val_accuracy: 0.7142 - val_loss: 1.5923 - learning_rate: 1.0000e-04
# Epoch 112/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8069 - loss: 1.0389
# Epoch 112: val_accuracy did not improve from 0.71488
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.8069 - loss: 1.0389 - val_accuracy: 0.7149 - val_loss: 1.5838 - learning_rate: 1.0000e-04
# Epoch 113/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8061 - loss: 1.0336
# Epoch 113: val_accuracy did not improve from 0.71488
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.8061 - loss: 1.0336 - val_accuracy: 0.7148 - val_loss: 1.5836 - learning_rate: 1.0000e-04
# Epoch 114/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8082 - loss: 1.0177
# Epoch 114: val_accuracy improved from 0.71488 to 0.71724, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.8082 - loss: 1.0177 - val_accuracy: 0.7172 - val_loss: 1.5765 - learning_rate: 1.0000e-04
# Epoch 115/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8079 - loss: 1.0164
# Epoch 115: val_accuracy did not improve from 0.71724
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.8079 - loss: 1.0164 - val_accuracy: 0.7169 - val_loss: 1.5737 - learning_rate: 1.0000e-04
# Epoch 116/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8109 - loss: 1.0027
# Epoch 116: val_accuracy did not improve from 0.71724
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8109 - loss: 1.0027 - val_accuracy: 0.7164 - val_loss: 1.5741 - learning_rate: 1.0000e-04
# Epoch 117/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8115 - loss: 0.9970
# Epoch 117: val_accuracy improved from 0.71724 to 0.71780, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 46s 23ms/step - accuracy: 0.8115 - loss: 0.9970 - val_accuracy: 0.7178 - val_loss: 1.5669 - learning_rate: 1.0000e-04
# Epoch 118/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8141 - loss: 0.9864
# Epoch 118: val_accuracy improved from 0.71780 to 0.71827, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.8141 - loss: 0.9864 - val_accuracy: 0.7183 - val_loss: 1.5648 - learning_rate: 1.0000e-04
# Epoch 119/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8126 - loss: 0.9827
# Epoch 119: val_accuracy did not improve from 0.71827
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8126 - loss: 0.9828 - val_accuracy: 0.7182 - val_loss: 1.5642 - learning_rate: 1.0000e-04
# Epoch 120/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8159 - loss: 0.9680
# Epoch 120: val_accuracy improved from 0.71827 to 0.71883, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8159 - loss: 0.9680 - val_accuracy: 0.7188 - val_loss: 1.5624 - learning_rate: 1.0000e-04
# Epoch 121/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8186 - loss: 0.9555
# Epoch 121: val_accuracy improved from 0.71883 to 0.72110, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.8186 - loss: 0.9555 - val_accuracy: 0.7211 - val_loss: 1.5630 - learning_rate: 1.0000e-04
# Epoch 122/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8200 - loss: 0.9510
# Epoch 122: val_accuracy did not improve from 0.72110
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8200 - loss: 0.9510 - val_accuracy: 0.7181 - val_loss: 1.5647 - learning_rate: 1.0000e-04
# Epoch 123/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8204 - loss: 0.9471
# Epoch 123: val_accuracy did not improve from 0.72110
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8204 - loss: 0.9471 - val_accuracy: 0.7181 - val_loss: 1.5600 - learning_rate: 1.0000e-04
# Epoch 124/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8174 - loss: 0.9506
# Epoch 124: val_accuracy did not improve from 0.72110
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.8174 - loss: 0.9506 - val_accuracy: 0.7209 - val_loss: 1.5537 - learning_rate: 1.0000e-04
# Epoch 125/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8212 - loss: 0.9310
# Epoch 125: val_accuracy improved from 0.72110 to 0.72238, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.8212 - loss: 0.9310 - val_accuracy: 0.7224 - val_loss: 1.5517 - learning_rate: 1.0000e-04
# Epoch 126/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8234 - loss: 0.9215
# Epoch 126: val_accuracy improved from 0.72238 to 0.72278, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.8234 - loss: 0.9215 - val_accuracy: 0.7228 - val_loss: 1.5574 - learning_rate: 1.0000e-04
# Epoch 127/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8239 - loss: 0.9229
# Epoch 127: val_accuracy did not improve from 0.72278
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8239 - loss: 0.9229 - val_accuracy: 0.7213 - val_loss: 1.5562 - learning_rate: 1.0000e-04
# Epoch 128/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8231 - loss: 0.9195
# Epoch 128: val_accuracy did not improve from 0.72278
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8231 - loss: 0.9195 - val_accuracy: 0.7223 - val_loss: 1.5515 - learning_rate: 1.0000e-04
# Epoch 129/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8240 - loss: 0.9146
# Epoch 129: val_accuracy did not improve from 0.72278
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8240 - loss: 0.9146 - val_accuracy: 0.7195 - val_loss: 1.5565 - learning_rate: 1.0000e-04
# Epoch 130/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8253 - loss: 0.9086
# Epoch 130: val_accuracy did not improve from 0.72278
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.8253 - loss: 0.9086 - val_accuracy: 0.7215 - val_loss: 1.5558 - learning_rate: 1.0000e-04
# Epoch 131/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8265 - loss: 0.8975
# Epoch 131: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 131: val_accuracy did not improve from 0.72278
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8265 - loss: 0.8975 - val_accuracy: 0.7225 - val_loss: 1.5547 - learning_rate: 1.0000e-04
# Epoch 132/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8316 - loss: 0.8832
# Epoch 132: val_accuracy improved from 0.72278 to 0.72390, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.8316 - loss: 0.8832 - val_accuracy: 0.7239 - val_loss: 1.5479 - learning_rate: 1.0000e-05
# Epoch 133/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8338 - loss: 0.8702
# Epoch 133: val_accuracy improved from 0.72390 to 0.72474, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.8338 - loss: 0.8702 - val_accuracy: 0.7247 - val_loss: 1.5457 - learning_rate: 1.0000e-05
# Epoch 134/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8376 - loss: 0.8597
# Epoch 134: val_accuracy improved from 0.72474 to 0.72571, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.8376 - loss: 0.8597 - val_accuracy: 0.7257 - val_loss: 1.5406 - learning_rate: 1.0000e-05
# Epoch 135/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8387 - loss: 0.8550
# Epoch 135: val_accuracy did not improve from 0.72571
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 82s 23ms/step - accuracy: 0.8387 - loss: 0.8550 - val_accuracy: 0.7252 - val_loss: 1.5380 - learning_rate: 1.0000e-05
# Epoch 136/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8393 - loss: 0.8498
# Epoch 136: val_accuracy improved from 0.72571 to 0.72621, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 82s 23ms/step - accuracy: 0.8393 - loss: 0.8498 - val_accuracy: 0.7262 - val_loss: 1.5384 - learning_rate: 1.0000e-05
# Epoch 137/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8403 - loss: 0.8489
# Epoch 137: val_accuracy improved from 0.72621 to 0.72639, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 82s 23ms/step - accuracy: 0.8403 - loss: 0.8489 - val_accuracy: 0.7264 - val_loss: 1.5354 - learning_rate: 1.0000e-05
# Epoch 138/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8416 - loss: 0.8415
# Epoch 138: val_accuracy did not improve from 0.72639
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8416 - loss: 0.8415 - val_accuracy: 0.7261 - val_loss: 1.5365 - learning_rate: 1.0000e-05
# Epoch 139/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8435 - loss: 0.8327
# Epoch 139: val_accuracy did not improve from 0.72639
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8435 - loss: 0.8327 - val_accuracy: 0.7263 - val_loss: 1.5358 - learning_rate: 1.0000e-05
# Epoch 140/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8409 - loss: 0.8406
# Epoch 140: val_accuracy did not improve from 0.72639
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.8409 - loss: 0.8406 - val_accuracy: 0.7260 - val_loss: 1.5356 - learning_rate: 1.0000e-05
# Epoch 141/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8434 - loss: 0.8330
# Epoch 141: val_accuracy improved from 0.72639 to 0.72658, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.8434 - loss: 0.8330 - val_accuracy: 0.7266 - val_loss: 1.5346 - learning_rate: 1.0000e-05
# Epoch 142/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8414 - loss: 0.8346
# Epoch 142: val_accuracy did not improve from 0.72658
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8414 - loss: 0.8346 - val_accuracy: 0.7265 - val_loss: 1.5376 - learning_rate: 1.0000e-05
# Epoch 143/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8445 - loss: 0.8315
# Epoch 143: val_accuracy improved from 0.72658 to 0.72664, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.8445 - loss: 0.8315 - val_accuracy: 0.7266 - val_loss: 1.5300 - learning_rate: 1.0000e-05
# Epoch 144/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8456 - loss: 0.8248
# Epoch 144: val_accuracy improved from 0.72664 to 0.72677, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.8456 - loss: 0.8248 - val_accuracy: 0.7268 - val_loss: 1.5319 - learning_rate: 1.0000e-05
# Epoch 145/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8427 - loss: 0.8307
# Epoch 145: val_accuracy did not improve from 0.72677
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8427 - loss: 0.8307 - val_accuracy: 0.7262 - val_loss: 1.5358 - learning_rate: 1.0000e-05
# Epoch 146/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8453 - loss: 0.8230
# Epoch 146: val_accuracy did not improve from 0.72677
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8453 - loss: 0.8230 - val_accuracy: 0.7266 - val_loss: 1.5334 - learning_rate: 1.0000e-05
# Epoch 147/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8430 - loss: 0.8301
# Epoch 147: val_accuracy improved from 0.72677 to 0.72705, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.8430 - loss: 0.8301 - val_accuracy: 0.7270 - val_loss: 1.5313 - learning_rate: 1.0000e-05
# Epoch 148/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8446 - loss: 0.8273
# Epoch 148: val_accuracy did not improve from 0.72705
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8446 - loss: 0.8273 - val_accuracy: 0.7268 - val_loss: 1.5335 - learning_rate: 1.0000e-05
# Epoch 149/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8444 - loss: 0.8176
# Epoch 149: val_accuracy improved from 0.72705 to 0.72779, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8444 - loss: 0.8176 - val_accuracy: 0.7278 - val_loss: 1.5327 - learning_rate: 1.0000e-05
# Epoch 150/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8469 - loss: 0.8167
# Epoch 150: val_accuracy did not improve from 0.72779
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.8469 - loss: 0.8167 - val_accuracy: 0.7276 - val_loss: 1.5312 - learning_rate: 1.0000e-05
# Epoch 151/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8471 - loss: 0.8150
# Epoch 151: val_accuracy did not improve from 0.72779
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8471 - loss: 0.8150 - val_accuracy: 0.7275 - val_loss: 1.5297 - learning_rate: 1.0000e-05
# Epoch 152/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8461 - loss: 0.8151
# Epoch 152: val_accuracy improved from 0.72779 to 0.72807, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.8461 - loss: 0.8151 - val_accuracy: 0.7281 - val_loss: 1.5291 - learning_rate: 1.0000e-05
# Epoch 153/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8504 - loss: 0.8084
# Epoch 153: val_accuracy improved from 0.72807 to 0.72826, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8503 - loss: 0.8084 - val_accuracy: 0.7283 - val_loss: 1.5286 - learning_rate: 1.0000e-05
# Epoch 154/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8453 - loss: 0.8124
# Epoch 154: val_accuracy did not improve from 0.72826
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.8453 - loss: 0.8125 - val_accuracy: 0.7280 - val_loss: 1.5277 - learning_rate: 1.0000e-05
# Epoch 155/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8453 - loss: 0.8195
# Epoch 155: val_accuracy did not improve from 0.72826
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.8453 - loss: 0.8195 - val_accuracy: 0.7272 - val_loss: 1.5273 - learning_rate: 1.0000e-05
# Epoch 156/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8474 - loss: 0.8095
# Epoch 156: val_accuracy did not improve from 0.72826
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8474 - loss: 0.8095 - val_accuracy: 0.7279 - val_loss: 1.5273 - learning_rate: 1.0000e-05
# Epoch 157/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8483 - loss: 0.8082
# Epoch 157: val_accuracy did not improve from 0.72826
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.8483 - loss: 0.8082 - val_accuracy: 0.7279 - val_loss: 1.5286 - learning_rate: 1.0000e-05
# Epoch 158/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8478 - loss: 0.8070
# Epoch 158: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 158: val_accuracy did not improve from 0.72826
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8478 - loss: 0.8070 - val_accuracy: 0.7275 - val_loss: 1.5247 - learning_rate: 1.0000e-05
# Epoch 159/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8496 - loss: 0.8024
# Epoch 159: val_accuracy improved from 0.72826 to 0.72838, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 23ms/step - accuracy: 0.8496 - loss: 0.8025 - val_accuracy: 0.7284 - val_loss: 1.5274 - learning_rate: 1.0000e-06
# Epoch 160/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8477 - loss: 0.8062
# Epoch 160: val_accuracy did not improve from 0.72838
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8477 - loss: 0.8062 - val_accuracy: 0.7275 - val_loss: 1.5264 - learning_rate: 1.0000e-06
# Epoch 161/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8489 - loss: 0.8001
# Epoch 161: val_accuracy did not improve from 0.72838
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8489 - loss: 0.8001 - val_accuracy: 0.7276 - val_loss: 1.5273 - learning_rate: 1.0000e-06
# Epoch 162/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8489 - loss: 0.8028
# Epoch 162: val_accuracy did not improve from 0.72838
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8489 - loss: 0.8028 - val_accuracy: 0.7274 - val_loss: 1.5246 - learning_rate: 1.0000e-06
# Epoch 163/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8502 - loss: 0.7994
# Epoch 165: val_accuracy did not improve from 0.72838
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8502 - loss: 0.7994 - val_accuracy: 0.7282 - val_loss: 1.5278 - learning_rate: 1.0000e-06
# Epoch 166/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8496 - loss: 0.8015
# Epoch 166: val_accuracy did not improve from 0.72838
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8496 - loss: 0.8015 - val_accuracy: 0.7280 - val_loss: 1.5286 - learning_rate: 1.0000e-06
# Epoch 167/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8492 - loss: 0.8031
# Epoch 167: val_accuracy did not improve from 0.72838
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8492 - loss: 0.8031 - val_accuracy: 0.7280 - val_loss: 1.5264 - learning_rate: 1.0000e-06
# Epoch 168/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8510 - loss: 0.7962
# Epoch 168: val_accuracy did not improve from 0.72838
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8510 - loss: 0.7962 - val_accuracy: 0.7278 - val_loss: 1.5263 - learning_rate: 1.0000e-06
# Epoch 169/200
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8507 - loss: 0.7973
# Epoch 169: val_accuracy did not improve from 0.72838
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8507 - loss: 0.7973 - val_accuracy: 0.7281 - val_loss: 1.5281 - learning_rate: 1.0000e-06
# Epoch 170/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8497 - loss: 0.8046
# Epoch 170: val_accuracy improved from 0.72838 to 0.72842, saving model to best_model.keras
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 82s 23ms/step - accuracy: 0.8497 - loss: 0.8046 - val_accuracy: 0.7284 - val_loss: 1.5257 - learning_rate: 1.0000e-06
# Epoch 171/200
# 2007/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8502 - loss: 0.7938
# Epoch 171: val_accuracy did not improve from 0.72842
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8502 - loss: 0.7938 - val_accuracy: 0.7284 - val_loss: 1.5260 - learning_rate: 1.0000e-06
# Epoch 172/200
# 2008/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8493 - loss: 0.8023
# Epoch 172: val_accuracy did not improve from 0.72842
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.8493 - loss: 0.8023 - val_accuracy: 0.7284 - val_loss: 1.5252 - learning_rate: 1.0000e-06
# Epoch 172: early stopping
# Restoring model weights from the end of the best epoch: 162.

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_accuracy:.5f}")
# Out:
# Test accuracy: 0.72739

# %%
# Learning Curve
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], marker='o')
plt.plot(history.history['val_accuracy'], marker='o')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'], marker='o')
plt.plot(history.history['val_loss'], marker='o')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

predictions = model.predict(X_test)
predicted_classes = np.argmax(predictions, axis=1)

true_classes = y_test  

class_labels = list(y_test.columns) if hasattr(y_test, 'columns') else None

if class_labels is None:
    unique_classes = np.unique(np.concatenate((true_classes, predicted_classes)))
    class_labels = [f"Class {i}" for i in unique_classes]

# Buat confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Print confusion matrix
print("Confusion Matrix:")
print(cm)

# Print classification report
print("\nClassification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))
# Out:
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step
# Confusion Matrix:
# [[437  11   7 ...  12   4   7]
#  [  3 522   1 ...   6   2   7]
#  [  7   5 548 ...  11   5   5]
#  ...
#  [ 10  11   4 ... 432   4   8]
#  [  0   2   0 ...   7 525   3]
#  [  8  13   0 ...   4   4 479]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.65      0.61      0.63       714
#      Class 1       0.62      0.73      0.67       714
#      Class 2       0.83      0.77      0.80       714
#      Class 3       0.62      0.64      0.63       714
#      Class 4       0.65      0.67      0.66       714
#      Class 5       0.66      0.74      0.70       714
#      Class 6       0.55      0.47      0.51       714
#      Class 7       0.87      0.90      0.88       714
#      Class 8       0.72      0.69      0.71       714
#      Class 9       0.87      0.86      0.86       714
#     Class 10       0.60      0.57      0.59       714
#     Class 11       0.61      0.65      0.63       714
#     Class 12       0.68      0.66      0.67       714
#     Class 13       0.80      0.81      0.80       714
#     Class 14       0.62      0.65      0.63       714
#     Class 15       0.78      0.80      0.79       714
#     Class 16       0.93      0.91      0.92       714
#     Class 17       0.64      0.63      0.63       714
#     Class 18       0.81      0.80      0.81       714
#     Class 19       0.79      0.77      0.78       714
#     Class 20       0.87      0.80      0.83       714
#     Class 21       0.85      0.85      0.85       714
#     Class 22       0.62      0.68      0.65       714
#     Class 23       0.82      0.80      0.81       714
#     Class 24       0.58      0.50      0.54       714
#     Class 25       0.74      0.80      0.77       714
#     Class 26       0.80      0.82      0.80       714
#     Class 27       0.83      0.72      0.77       714
#     Class 28       0.82      0.87      0.84       714
#     Class 29       0.70      0.73      0.71       714
#     Class 30       0.56      0.57      0.56       714
#     Class 31       0.53      0.59      0.56       714
#     Class 32       0.57      0.59      0.58       714
#     Class 33       0.88      0.83      0.85       714
#     Class 34       0.86      0.86      0.86       714
#     Class 35       0.70      0.69      0.70       714
#     Class 36       0.85      0.89      0.87       714
#     Class 37       0.94      0.90      0.92       714
#     Class 38       0.70      0.69      0.69       714
#     Class 39       0.75      0.68      0.71       714
#     Class 40       0.80      0.79      0.80       714
#     Class 41       0.77      0.76      0.76       714
#     Class 42       0.59      0.61      0.60       714
#     Class 43       0.72      0.74      0.73       714
#     Class 44       0.68      0.67      0.68       714
#
#     accuracy                           0.73     32130
#    macro avg       0.73      0.73      0.73     32130
# weighted avg       0.73      0.73      0.73     32130
