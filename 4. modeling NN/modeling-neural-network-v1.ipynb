# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import joblib
from sklearn.model_selection import KFold

# %%
df = pd.read_csv(r"/kaggle/input/feature-common-language/audio_features_partial.csv")
df.head()
# Out:
#    chroma_stft       rms  spectral_centroid  spectral_bandwidth  \
# 0     0.712224  0.055740        2989.050985         2193.800068
# 1     0.598403  0.074004        2372.315827         2065.561020
# 2     0.756316  0.046051        3274.178654         2196.474265
# 3     0.588983  0.061376        1948.418292         2049.242741
# 4     0.647222  0.069638        1705.618989         1824.714129
#
#    spectral_rolloff  zero_crossing_rate     mfcc_1     mfcc_2     mfcc_3  \
# 0       5666.294643            0.275144 -202.32579  27.614292   4.094784
# 1       4795.649510            0.178041 -137.41476  59.931843   5.077963
# 2       5870.572917            0.353054 -233.02031  22.691550  10.057923
# 3       4186.921296            0.137682 -199.04490  80.806870  31.451380
# 4       3730.709877            0.095540 -325.47556  92.373820  17.725632
#
#       mfcc_4  ...    mfcc_13   mfcc_14    mfcc_15   mfcc_16   mfcc_17  \
# 0   5.301181  ...   4.752774 -0.985637  -6.752584 -4.679379 -5.478848
# 1  -5.712012  ... -12.469353 -2.134825 -10.989368 -1.460541 -4.485021
# 2   3.829097  ...  -1.657243 -5.409642  -4.017134 -6.744406 -1.697630
# 3  -1.297673  ...  -4.202263  0.065943  -9.312079 -7.164060 -3.082040
# 4  31.867613  ...   3.169903  4.538502  -1.073114 -1.204524 -0.108214
#
#     mfcc_18   mfcc_19   mfcc_20   label  \
# 0 -0.866508 -1.919669 -0.634521  Arabic
# 1 -0.408789 -8.211143 -5.170048  Arabic
# 2 -0.387302  0.829549  1.292110  Arabic
# 3 -8.046175 -3.083879 -2.018449  Arabic
# 4 -4.803460 -2.882802 -1.455632  Arabic
#
#                                            file_path
# 0  /kaggle/input/preprocess-common-language/proce...
# 1  /kaggle/input/preprocess-common-language/proce...
# 2  /kaggle/input/preprocess-common-language/proce...
# 3  /kaggle/input/preprocess-common-language/proce...
# 4  /kaggle/input/preprocess-common-language/proce...
#
# [5 rows x 28 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Fit LabelEncoder with your actual labels
label_encoder.fit(df['label'])

# Transform actual labels to numeric labels
df['numeric_labels'] = label_encoder.transform(df['label'])

# %%
X = df.drop(columns=['label','numeric_labels','file_path'])
y = df['numeric_labels']

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(sampling_strategy='auto', random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# %%
from collections import Counter

# Jumlah kelas sebelum SMOTE
print("Jumlah kelas sebelum SMOTE:")
print(Counter(y))

# Jumlah kelas setelah SMOTE
print("\nJumlah kelas setelah SMOTE:")
print(Counter(y_resampled))
# Out:
# Jumlah kelas sebelum SMOTE:
# Counter({2: 3570, 39: 3177, 19: 3012, 6: 3003, 27: 2955, 41: 2784, 24: 2766, 0: 2751, 20: 2733, 37: 2691, 10: 2550, 33: 2547, 18: 2520, 21: 2484, 42: 2472, 8: 2442, 40: 2367, 26: 2331, 30: 2283, 28: 2277, 23: 2268, 32: 2238, 7: 2202, 31: 2196, 43: 2181, 15: 2073, 44: 2073, 5: 2016, 34: 1977, 9: 1962, 25: 1947, 12: 1932, 1: 1914, 16: 1890, 29: 1884, 14: 1863, 3: 1830, 17: 1830, 4: 1797, 11: 1773, 35: 1758, 36: 1752, 38: 1737, 22: 1695, 13: 1623})
#
# Jumlah kelas setelah SMOTE:
# Counter({0: 3570, 4: 3570, 9: 3570, 27: 3570, 18: 3570, 24: 3570, 23: 3570, 13: 3570, 20: 3570, 11: 3570, 16: 3570, 40: 3570, 28: 3570, 15: 3570, 21: 3570, 8: 3570, 31: 3570, 29: 3570, 5: 3570, 7: 3570, 41: 3570, 44: 3570, 3: 3570, 2: 3570, 14: 3570, 43: 3570, 36: 3570, 26: 3570, 34: 3570, 12: 3570, 37: 3570, 35: 3570, 42: 3570, 33: 3570, 17: 3570, 25: 3570, 6: 3570, 30: 3570, 39: 3570, 22: 3570, 10: 3570, 1: 3570, 19: 3570, 32: 3570, 38: 3570})

# %%
### split data 80% 20%

X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled,
                                                    test_size=0.2, random_state=42,
                                                    stratify=y_resampled)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input, BatchNormalization
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.regularizers import l1_l2

# %%
num_classes = len(label_encoder.classes_)
input_dim=X_train.shape[1]

model = Sequential()
model.add(Input(shape=(input_dim,)))
model.add(Dense(256, activation='relu', kernel_regularizer=l1_l2(l1=0.01, l2=0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu', kernel_regularizer=l1_l2(l1=0.01, l2=0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu', kernel_regularizer=l1_l2(l1=0.01, l2=0.01)))
model.add(BatchNormalization())        
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 256)            │         6,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 45)             │         2,925 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 52,781 (206.18 KB)
#  Trainable params: 51,885 (202.68 KB)
#  Non-trainable params: 896 (3.50 KB)

# %%
model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import datetime


# Membuat callback EarlyStopping
early_stopping = EarlyStopping(
    monitor='val_loss', 
    patience=10,         
    restore_best_weights=True, 
    verbose=1
)

reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=5, min_lr=0.000001, verbose=1)

model_checkpoint = ModelCheckpoint('best_model.keras', 
                                   save_best_only=True, 
                                   monitor='val_accuracy',
                                   mode='max', 
                                   verbose=1)

log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

history = model.fit(
    X_train, y_train,
    validation_data=(X_test,y_test),
    epochs=200,
    batch_size=32,
    callbacks=[early_stopping, reduce_lr, model_checkpoint, tensorboard_callback],
    verbose=1
)
# Out:
# Epoch 1/100
#   36/4017 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.0178 - loss: 37.2808
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1720017384.427271    2460 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1720017384.443984    2460 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0282 - loss: 8.2884
# W0000 00:00:1720017402.445389    2458 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_accuracy improved from -inf to 0.02730, saving model to best_model.keras
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - accuracy: 0.0282 - loss: 8.2876 - val_accuracy: 0.0273 - val_loss: 4.1504 - learning_rate: 0.0010
# Epoch 2/100
# 4007/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0336 - loss: 3.9906
# Epoch 2: val_accuracy did not improve from 0.02730
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0336 - loss: 3.9906 - val_accuracy: 0.0229 - val_loss: 4.1150 - learning_rate: 0.0010
# Epoch 3/100
# 4012/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0333 - loss: 3.9885
# Epoch 3: val_accuracy improved from 0.02730 to 0.02916, saving model to best_model.keras
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0333 - loss: 3.9885 - val_accuracy: 0.0292 - val_loss: 3.9632 - learning_rate: 0.0010
# Epoch 4/100
# 4013/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0340 - loss: 3.9554
# Epoch 4: val_accuracy did not improve from 0.02916
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0340 - loss: 3.9554 - val_accuracy: 0.0271 - val_loss: 4.0663 - learning_rate: 0.0010
# Epoch 5/100
# 4013/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0331 - loss: 3.9501
# Epoch 5: val_accuracy did not improve from 0.02916
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0331 - loss: 3.9501 - val_accuracy: 0.0282 - val_loss: 4.0802 - learning_rate: 0.0010
# Epoch 6/100
# 4007/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0354 - loss: 3.9307
# Epoch 6: val_accuracy did not improve from 0.02916
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0354 - loss: 3.9307 - val_accuracy: 0.0255 - val_loss: 3.9731 - learning_rate: 0.0010
# Epoch 7/100
# 4011/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0350 - loss: 3.9155
# Epoch 7: val_accuracy did not improve from 0.02916
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.0350 - loss: 3.9155 - val_accuracy: 0.0262 - val_loss: 4.0392 - learning_rate: 0.0010
# Epoch 8/100
# 4010/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0351 - loss: 3.9002
# Epoch 8: val_accuracy improved from 0.02916 to 0.03143, saving model to best_model.keras
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0351 - loss: 3.9002 - val_accuracy: 0.0314 - val_loss: 3.9145 - learning_rate: 0.0010
# Epoch 9/100
# 4014/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0347 - loss: 3.9015
# Epoch 9: val_accuracy did not improve from 0.03143
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0347 - loss: 3.9015 - val_accuracy: 0.0307 - val_loss: 3.9007 - learning_rate: 0.0010
# Epoch 10/100
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0344 - loss: 3.8984
# Epoch 10: val_accuracy did not improve from 0.03143
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0344 - loss: 3.8984 - val_accuracy: 0.0250 - val_loss: 3.9214 - learning_rate: 0.0010
# Epoch 11/100
# 4016/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0317 - loss: 3.8982
# Epoch 11: val_accuracy improved from 0.03143 to 0.03452, saving model to best_model.keras
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0317 - loss: 3.8982 - val_accuracy: 0.0345 - val_loss: 3.8875 - learning_rate: 0.0010
# Epoch 12/100
# 4000/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0347 - loss: 3.8808
# Epoch 12: val_accuracy did not improve from 0.03452
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0347 - loss: 3.8808 - val_accuracy: 0.0263 - val_loss: 3.9304 - learning_rate: 0.0010
# Epoch 13/100
# 4015/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0346 - loss: 3.8810
# Epoch 13: val_accuracy did not improve from 0.03452
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0346 - loss: 3.8810 - val_accuracy: 0.0234 - val_loss: 3.9422 - learning_rate: 0.0010
# Epoch 14/100
# 4010/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0329 - loss: 3.8834
# Epoch 14: val_accuracy did not improve from 0.03452
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0329 - loss: 3.8834 - val_accuracy: 0.0306 - val_loss: 3.9340 - learning_rate: 0.0010
# Epoch 15/100
# 4016/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0350 - loss: 3.8826
# Epoch 15: val_accuracy did not improve from 0.03452
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0350 - loss: 3.8826 - val_accuracy: 0.0227 - val_loss: 4.0532 - learning_rate: 0.0010
# Epoch 16/100
# 4000/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0305 - loss: 3.8914
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 16: val_accuracy did not improve from 0.03452
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0305 - loss: 3.8913 - val_accuracy: 0.0328 - val_loss: 3.8640 - learning_rate: 0.0010
# Epoch 17/100
# 4001/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0357 - loss: 3.8010
# Epoch 17: val_accuracy did not improve from 0.03452
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0357 - loss: 3.8010 - val_accuracy: 0.0223 - val_loss: 3.9870 - learning_rate: 1.0000e-04
# Epoch 18/100
# 4007/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0355 - loss: 3.7937
# Epoch 18: val_accuracy improved from 0.03452 to 0.03791, saving model to best_model.keras
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0355 - loss: 3.7937 - val_accuracy: 0.0379 - val_loss: 3.7866 - learning_rate: 1.0000e-04
# Epoch 19/100
# 3999/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0379 - loss: 3.7817
# Epoch 19: val_accuracy improved from 0.03791 to 0.04460, saving model to best_model.keras
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - accuracy: 0.0379 - loss: 3.7817 - val_accuracy: 0.0446 - val_loss: 3.7591 - learning_rate: 1.0000e-04
# Epoch 20/100
# 4009/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0389 - loss: 3.7693
# Epoch 20: val_accuracy did not improve from 0.04460
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0389 - loss: 3.7693 - val_accuracy: 0.0298 - val_loss: 3.7909 - learning_rate: 1.0000e-04
# Epoch 21/100
# 4010/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0389 - loss: 3.7621
# Epoch 21: val_accuracy did not improve from 0.04460
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0389 - loss: 3.7621 - val_accuracy: 0.0346 - val_loss: 3.8378 - learning_rate: 1.0000e-04
# Epoch 22/100
# 4015/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0430 - loss: 3.7557
# Epoch 22: val_accuracy did not improve from 0.04460
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0430 - loss: 3.7557 - val_accuracy: 0.0417 - val_loss: 3.7649 - learning_rate: 1.0000e-04
# Epoch 23/100
# 4016/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0431 - loss: 3.7555
# Epoch 23: val_accuracy did not improve from 0.04460
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0431 - loss: 3.7555 - val_accuracy: 0.0414 - val_loss: 3.7521 - learning_rate: 1.0000e-04
# Epoch 24/100
# 4000/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0421 - loss: 3.7534
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 24: val_accuracy did not improve from 0.04460
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0421 - loss: 3.7534 - val_accuracy: 0.0353 - val_loss: 3.7802 - learning_rate: 1.0000e-04
# Epoch 25/100
# 4000/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0435 - loss: 3.7492
# Epoch 25: val_accuracy improved from 0.04460 to 0.05758, saving model to best_model.keras
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0435 - loss: 3.7492 - val_accuracy: 0.0576 - val_loss: 3.7162 - learning_rate: 1.0000e-05
# Epoch 26/100
# 4003/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0434 - loss: 3.7410
# Epoch 26: val_accuracy did not improve from 0.05758
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0434 - loss: 3.7410 - val_accuracy: 0.0536 - val_loss: 3.7262 - learning_rate: 1.0000e-05
# Epoch 27/100
# 4008/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0456 - loss: 3.7363
# Epoch 27: val_accuracy did not improve from 0.05758
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0456 - loss: 3.7363 - val_accuracy: 0.0565 - val_loss: 3.7111 - learning_rate: 1.0000e-05
# Epoch 28/100
# 4011/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0456 - loss: 3.7307
# Epoch 28: val_accuracy did not improve from 0.05758
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0456 - loss: 3.7307 - val_accuracy: 0.0528 - val_loss: 3.7134 - learning_rate: 1.0000e-05
# Epoch 29/100
# 4015/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0454 - loss: 3.7353
# Epoch 29: val_accuracy did not improve from 0.05758
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0454 - loss: 3.7353 - val_accuracy: 0.0539 - val_loss: 3.7082 - learning_rate: 1.0000e-05
# Epoch 30/100
# 4004/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0456 - loss: 3.7316
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 30: val_accuracy did not improve from 0.05758
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0456 - loss: 3.7316 - val_accuracy: 0.0464 - val_loss: 3.7204 - learning_rate: 1.0000e-05
# Epoch 31/100
# 4003/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0451 - loss: 3.7295
# Epoch 31: val_accuracy improved from 0.05758 to 0.05773, saving model to best_model.keras
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0451 - loss: 3.7295 - val_accuracy: 0.0577 - val_loss: 3.6999 - learning_rate: 1.0000e-06
# Epoch 32/100
# 4013/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0469 - loss: 3.7290
# Epoch 32: val_accuracy did not improve from 0.05773
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0469 - loss: 3.7290 - val_accuracy: 0.0554 - val_loss: 3.7000 - learning_rate: 1.0000e-06
# Epoch 33/100
# 4003/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0462 - loss: 3.7272
# Epoch 33: val_accuracy did not improve from 0.05773
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0462 - loss: 3.7272 - val_accuracy: 0.0566 - val_loss: 3.6962 - learning_rate: 1.0000e-06
# Epoch 34/100
# 4012/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0453 - loss: 3.7261
# Epoch 34: val_accuracy did not improve from 0.05773
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0453 - loss: 3.7261 - val_accuracy: 0.0550 - val_loss: 3.6957 - learning_rate: 1.0000e-06
# Epoch 35/100
# 3998/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0464 - loss: 3.7257
# Epoch 35: val_accuracy did not improve from 0.05773
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0464 - loss: 3.7257 - val_accuracy: 0.0563 - val_loss: 3.6947 - learning_rate: 1.0000e-06
# Epoch 36/100
# 4015/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0460 - loss: 3.7245
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 36: val_accuracy did not improve from 0.05773
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0460 - loss: 3.7245 - val_accuracy: 0.0571 - val_loss: 3.6979 - learning_rate: 1.0000e-06
# Epoch 37/100
# 4010/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0465 - loss: 3.7251
# Epoch 37: val_accuracy did not improve from 0.05773
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0465 - loss: 3.7251 - val_accuracy: 0.0556 - val_loss: 3.6948 - learning_rate: 1.0000e-06
# Epoch 38/100
# 4011/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0475 - loss: 3.7229
# Epoch 38: val_accuracy did not improve from 0.05773
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0475 - loss: 3.7229 - val_accuracy: 0.0571 - val_loss: 3.6952 - learning_rate: 1.0000e-06
# Epoch 39/100
# 4000/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0468 - loss: 3.7237
# Epoch 39: val_accuracy improved from 0.05773 to 0.05795, saving model to best_model.keras
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0468 - loss: 3.7237 - val_accuracy: 0.0580 - val_loss: 3.6918 - learning_rate: 1.0000e-06
# Epoch 40/100
# 4013/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0475 - loss: 3.7220
# Epoch 40: val_accuracy did not improve from 0.05795
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0475 - loss: 3.7220 - val_accuracy: 0.0572 - val_loss: 3.6951 - learning_rate: 1.0000e-06
# Epoch 41/100
# 4009/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0474 - loss: 3.7214
# Epoch 41: val_accuracy improved from 0.05795 to 0.05861, saving model to best_model.keras
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0474 - loss: 3.7214 - val_accuracy: 0.0586 - val_loss: 3.6929 - learning_rate: 1.0000e-06
# Epoch 42/100
# 4004/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0478 - loss: 3.7204
# Epoch 42: val_accuracy did not improve from 0.05861
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0478 - loss: 3.7204 - val_accuracy: 0.0561 - val_loss: 3.6942 - learning_rate: 1.0000e-06
# Epoch 43/100
# 4001/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0495 - loss: 3.7157
# Epoch 43: val_accuracy did not improve from 0.05861
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0494 - loss: 3.7158 - val_accuracy: 0.0543 - val_loss: 3.6942 - learning_rate: 1.0000e-06
# Epoch 44/100
# 4005/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0475 - loss: 3.7210
# Epoch 44: val_accuracy improved from 0.05861 to 0.05873, saving model to best_model.keras
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0475 - loss: 3.7210 - val_accuracy: 0.0587 - val_loss: 3.6930 - learning_rate: 1.0000e-06
# Epoch 45/100
# 4016/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0479 - loss: 3.7216
# Epoch 45: val_accuracy did not improve from 0.05873
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0479 - loss: 3.7216 - val_accuracy: 0.0561 - val_loss: 3.6912 - learning_rate: 1.0000e-06
# Epoch 46/100
# 4016/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0469 - loss: 3.7227
# Epoch 46: val_accuracy did not improve from 0.05873
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0469 - loss: 3.7227 - val_accuracy: 0.0554 - val_loss: 3.6936 - learning_rate: 1.0000e-06
# Epoch 47/100
# 4011/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0483 - loss: 3.7180
# Epoch 47: val_accuracy did not improve from 0.05873
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0483 - loss: 3.7180 - val_accuracy: 0.0586 - val_loss: 3.6885 - learning_rate: 1.0000e-06
# Epoch 48/100
# 4003/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0469 - loss: 3.7197
# Epoch 48: val_accuracy did not improve from 0.05873
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0469 - loss: 3.7196 - val_accuracy: 0.0576 - val_loss: 3.6889 - learning_rate: 1.0000e-06
# Epoch 49/100
# 4016/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0482 - loss: 3.7170
# Epoch 49: val_accuracy improved from 0.05873 to 0.05917, saving model to best_model.keras
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0482 - loss: 3.7170 - val_accuracy: 0.0592 - val_loss: 3.6902 - learning_rate: 1.0000e-06
# Epoch 50/100
# 4007/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0479 - loss: 3.7185
# Epoch 50: val_accuracy did not improve from 0.05917
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0479 - loss: 3.7185 - val_accuracy: 0.0588 - val_loss: 3.6881 - learning_rate: 1.0000e-06
# Epoch 51/100
# 3998/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0487 - loss: 3.7165
# Epoch 51: val_accuracy did not improve from 0.05917
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0487 - loss: 3.7165 - val_accuracy: 0.0589 - val_loss: 3.6900 - learning_rate: 1.0000e-06
# Epoch 52/100
# 4006/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0475 - loss: 3.7167
# Epoch 52: val_accuracy improved from 0.05917 to 0.05945, saving model to best_model.keras
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0475 - loss: 3.7167 - val_accuracy: 0.0594 - val_loss: 3.6913 - learning_rate: 1.0000e-06
# Epoch 53/100
# 4006/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0487 - loss: 3.7179
# Epoch 53: val_accuracy did not improve from 0.05945
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.0487 - loss: 3.7178 - val_accuracy: 0.0585 - val_loss: 3.6944 - learning_rate: 1.0000e-06
# Epoch 54/100
# 4002/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0495 - loss: 3.7154
# Epoch 54: val_accuracy did not improve from 0.05945
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0495 - loss: 3.7155 - val_accuracy: 0.0564 - val_loss: 3.6928 - learning_rate: 1.0000e-06
# Epoch 55/100
# 4005/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0486 - loss: 3.7162
# Epoch 55: val_accuracy did not improve from 0.05945
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0486 - loss: 3.7162 - val_accuracy: 0.0540 - val_loss: 3.7129 - learning_rate: 1.0000e-06
# Epoch 56/100
# 4005/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0493 - loss: 3.7137
# Epoch 56: val_accuracy did not improve from 0.05945
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0493 - loss: 3.7137 - val_accuracy: 0.0545 - val_loss: 3.6975 - learning_rate: 1.0000e-06
# Epoch 57/100
# 4002/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0497 - loss: 3.7165
# Epoch 57: val_accuracy did not improve from 0.05945
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0497 - loss: 3.7165 - val_accuracy: 0.0580 - val_loss: 3.6877 - learning_rate: 1.0000e-06
# Epoch 58/100
# 4010/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0474 - loss: 3.7150
# Epoch 58: val_accuracy improved from 0.05945 to 0.05954, saving model to best_model.keras
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0474 - loss: 3.7150 - val_accuracy: 0.0595 - val_loss: 3.6896 - learning_rate: 1.0000e-06
# Epoch 59/100
# 4008/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0478 - loss: 3.7174
# Epoch 59: val_accuracy did not improve from 0.05954
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0478 - loss: 3.7174 - val_accuracy: 0.0569 - val_loss: 3.6953 - learning_rate: 1.0000e-06
# Epoch 60/100
# 4013/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0501 - loss: 3.7145
# Epoch 60: val_accuracy improved from 0.05954 to 0.06001, saving model to best_model.keras
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0501 - loss: 3.7145 - val_accuracy: 0.0600 - val_loss: 3.6880 - learning_rate: 1.0000e-06
# Epoch 61/100
# 4016/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0484 - loss: 3.7155
# Epoch 61: val_accuracy did not improve from 0.06001
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.0484 - loss: 3.7155 - val_accuracy: 0.0587 - val_loss: 3.6872 - learning_rate: 1.0000e-06
# Epoch 62/100
# 4012/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0500 - loss: 3.7147
# Epoch 62: val_accuracy did not improve from 0.06001
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0500 - loss: 3.7147 - val_accuracy: 0.0588 - val_loss: 3.6911 - learning_rate: 1.0000e-06
# Epoch 63/100
# 4002/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0495 - loss: 3.7124
# Epoch 63: val_accuracy improved from 0.06001 to 0.06016, saving model to best_model.keras
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0495 - loss: 3.7124 - val_accuracy: 0.0602 - val_loss: 3.6881 - learning_rate: 1.0000e-06
# Epoch 64/100
# 4009/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0491 - loss: 3.7141
# Epoch 64: val_accuracy did not improve from 0.06016
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.0491 - loss: 3.7141 - val_accuracy: 0.0584 - val_loss: 3.6869 - learning_rate: 1.0000e-06
# Epoch 65/100
# 4000/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0491 - loss: 3.7133
# Epoch 65: val_accuracy improved from 0.06016 to 0.06035, saving model to best_model.keras
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0491 - loss: 3.7133 - val_accuracy: 0.0603 - val_loss: 3.6861 - learning_rate: 1.0000e-06
# Epoch 66/100
# 4007/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0485 - loss: 3.7140
# Epoch 66: val_accuracy improved from 0.06035 to 0.06144, saving model to best_model.keras
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0485 - loss: 3.7140 - val_accuracy: 0.0614 - val_loss: 3.6844 - learning_rate: 1.0000e-06
# Epoch 67/100
# 4002/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0493 - loss: 3.7134
# Epoch 67: val_accuracy did not improve from 0.06144
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.0493 - loss: 3.7134 - val_accuracy: 0.0605 - val_loss: 3.6895 - learning_rate: 1.0000e-06
# Epoch 68/100
# 4007/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0504 - loss: 3.7138
# Epoch 68: val_accuracy did not improve from 0.06144
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0504 - loss: 3.7138 - val_accuracy: 0.0611 - val_loss: 3.6843 - learning_rate: 1.0000e-06
# Epoch 69/100
# 4016/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0488 - loss: 3.7150
# Epoch 69: val_accuracy did not improve from 0.06144
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.0488 - loss: 3.7150 - val_accuracy: 0.0606 - val_loss: 3.6847 - learning_rate: 1.0000e-06
# Epoch 70/100
# 4001/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0487 - loss: 3.7130
# Epoch 70: val_accuracy did not improve from 0.06144
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.0487 - loss: 3.7130 - val_accuracy: 0.0596 - val_loss: 3.6852 - learning_rate: 1.0000e-06
# Epoch 71/100
# 4003/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0495 - loss: 3.7128
# Epoch 71: val_accuracy did not improve from 0.06144
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0495 - loss: 3.7128 - val_accuracy: 0.0611 - val_loss: 3.6843 - learning_rate: 1.0000e-06
# Epoch 72/100
# 4000/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0499 - loss: 3.7135
# Epoch 72: val_accuracy did not improve from 0.06144
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.0499 - loss: 3.7135 - val_accuracy: 0.0590 - val_loss: 3.6927 - learning_rate: 1.0000e-06
# Epoch 73/100
# 4000/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0495 - loss: 3.7133
# Epoch 73: val_accuracy did not improve from 0.06144
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.0495 - loss: 3.7133 - val_accuracy: 0.0594 - val_loss: 3.6851 - learning_rate: 1.0000e-06
# Epoch 74/100
# 4005/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0491 - loss: 3.7156
# Epoch 74: val_accuracy did not improve from 0.06144
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.0491 - loss: 3.7156 - val_accuracy: 0.0602 - val_loss: 3.6865 - learning_rate: 1.0000e-06
# Epoch 75/100
# 4012/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0498 - loss: 3.7129
# Epoch 75: val_accuracy did not improve from 0.06144
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.0498 - loss: 3.7129 - val_accuracy: 0.0522 - val_loss: 3.7076 - learning_rate: 1.0000e-06
# Epoch 76/100
# 4001/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0483 - loss: 3.7151
# Epoch 76: val_accuracy did not improve from 0.06144
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.0483 - loss: 3.7150 - val_accuracy: 0.0596 - val_loss: 3.6827 - learning_rate: 1.0000e-06
# Epoch 77/100
# 4002/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0489 - loss: 3.7124
# Epoch 77: val_accuracy did not improve from 0.06144
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.0489 - loss: 3.7124 - val_accuracy: 0.0608 - val_loss: 3.6884 - learning_rate: 1.0000e-06
# Epoch 78/100
# 4012/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0498 - loss: 3.7120
# Epoch 78: val_accuracy did not improve from 0.06144
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0498 - loss: 3.7120 - val_accuracy: 0.0518 - val_loss: 3.6989 - learning_rate: 1.0000e-06
# Epoch 79/100
# 4007/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0501 - loss: 3.7135
# Epoch 79: val_accuracy improved from 0.06144 to 0.06166, saving model to best_model.keras
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0501 - loss: 3.7135 - val_accuracy: 0.0617 - val_loss: 3.6848 - learning_rate: 1.0000e-06
# Epoch 80/100
# 3999/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0488 - loss: 3.7141
# Epoch 80: val_accuracy improved from 0.06166 to 0.06184, saving model to best_model.keras
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.0488 - loss: 3.7141 - val_accuracy: 0.0618 - val_loss: 3.6828 - learning_rate: 1.0000e-06
# Epoch 81/100
# 4008/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0504 - loss: 3.7140
# Epoch 81: val_accuracy did not improve from 0.06184
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.0504 - loss: 3.7140 - val_accuracy: 0.0612 - val_loss: 3.6880 - learning_rate: 1.0000e-06
# Epoch 82/100
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0496 - loss: 3.7107
# Epoch 82: val_accuracy did not improve from 0.06184
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0496 - loss: 3.7107 - val_accuracy: 0.0536 - val_loss: 3.7098 - learning_rate: 1.0000e-06
# Epoch 83/100
# 4004/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0507 - loss: 3.7129
# Epoch 83: val_accuracy did not improve from 0.06184
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.0507 - loss: 3.7129 - val_accuracy: 0.0597 - val_loss: 3.6893 - learning_rate: 1.0000e-06
# Epoch 84/100
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0512 - loss: 3.7132
# Epoch 84: val_accuracy did not improve from 0.06184
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.0512 - loss: 3.7132 - val_accuracy: 0.0607 - val_loss: 3.6884 - learning_rate: 1.0000e-06
# Epoch 85/100
# 4010/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0514 - loss: 3.7102
# Epoch 85: val_accuracy did not improve from 0.06184
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0514 - loss: 3.7102 - val_accuracy: 0.0589 - val_loss: 3.6831 - learning_rate: 1.0000e-06
# Epoch 86/100
# 4010/4017 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0506 - loss: 3.7095
# Epoch 86: val_accuracy improved from 0.06184 to 0.06293, saving model to best_model.keras
# 4017/4017 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.0506 - loss: 3.7095 - val_accuracy: 0.0629 - val_loss: 3.6843 - learning_rate: 1.0000e-06
# Epoch 86: early stopping
# Restoring model weights from the end of the best epoch: 76.

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_accuracy:.5f}")
# Out:
# Test accuracy: 0.05960

# %%
# Learning Curve
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], marker='o')
plt.plot(history.history['val_accuracy'], marker='o')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='lower right')
plt.show()
