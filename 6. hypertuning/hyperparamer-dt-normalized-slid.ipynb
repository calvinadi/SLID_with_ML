# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import joblib
from sklearn.model_selection import KFold

# %%
df = pd.read_csv(r"/kaggle/input/feature-common-language/audio_features_partial.csv")
df.head()
# Out:
#    chroma_stft       rms  spectral_centroid  spectral_bandwidth  \
# 0     0.712224  0.055740        2989.050985         2193.800068
# 1     0.598403  0.074004        2372.315827         2065.561020
# 2     0.756316  0.046051        3274.178654         2196.474265
# 3     0.588983  0.061376        1948.418292         2049.242741
# 4     0.647222  0.069638        1705.618989         1824.714129
#
#    spectral_rolloff  zero_crossing_rate     mfcc_1     mfcc_2     mfcc_3  \
# 0       5666.294643            0.275144 -202.32579  27.614292   4.094784
# 1       4795.649510            0.178041 -137.41476  59.931843   5.077963
# 2       5870.572917            0.353054 -233.02031  22.691550  10.057923
# 3       4186.921296            0.137682 -199.04490  80.806870  31.451380
# 4       3730.709877            0.095540 -325.47556  92.373820  17.725632
#
#       mfcc_4  ...    mfcc_13   mfcc_14    mfcc_15   mfcc_16   mfcc_17  \
# 0   5.301181  ...   4.752774 -0.985637  -6.752584 -4.679379 -5.478848
# 1  -5.712012  ... -12.469353 -2.134825 -10.989368 -1.460541 -4.485021
# 2   3.829097  ...  -1.657243 -5.409642  -4.017134 -6.744406 -1.697630
# 3  -1.297673  ...  -4.202263  0.065943  -9.312079 -7.164060 -3.082040
# 4  31.867613  ...   3.169903  4.538502  -1.073114 -1.204524 -0.108214
#
#     mfcc_18   mfcc_19   mfcc_20   label  \
# 0 -0.866508 -1.919669 -0.634521  Arabic
# 1 -0.408789 -8.211143 -5.170048  Arabic
# 2 -0.387302  0.829549  1.292110  Arabic
# 3 -8.046175 -3.083879 -2.018449  Arabic
# 4 -4.803460 -2.882802 -1.455632  Arabic
#
#                                            file_path
# 0  /kaggle/input/preprocess-common-language/proce...
# 1  /kaggle/input/preprocess-common-language/proce...
# 2  /kaggle/input/preprocess-common-language/proce...
# 3  /kaggle/input/preprocess-common-language/proce...
# 4  /kaggle/input/preprocess-common-language/proce...
#
# [5 rows x 28 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Fit LabelEncoder with your actual labels
label_encoder.fit(df['label'])

# Transform actual labels to numeric labels
df['numeric_labels'] = label_encoder.transform(df['label'])

# %%
X = df.drop(columns=['label','numeric_labels','file_path'])
y = df['numeric_labels']

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(sampling_strategy='auto', random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# %%
from collections import Counter

# Jumlah kelas sebelum SMOTE
print("Jumlah kelas sebelum SMOTE:")
print(Counter(y))

# Jumlah kelas setelah SMOTE
print("\nJumlah kelas setelah SMOTE:")
print(Counter(y_resampled))
# Out:
# Jumlah kelas sebelum SMOTE:
# Counter({2: 3570, 39: 3177, 19: 3012, 6: 3003, 27: 2955, 41: 2784, 24: 2766, 0: 2751, 20: 2733, 37: 2691, 10: 2550, 33: 2547, 18: 2520, 21: 2484, 42: 2472, 8: 2442, 40: 2367, 26: 2331, 30: 2283, 28: 2277, 23: 2268, 32: 2238, 7: 2202, 31: 2196, 43: 2181, 15: 2073, 44: 2073, 5: 2016, 34: 1977, 9: 1962, 25: 1947, 12: 1932, 1: 1914, 16: 1890, 29: 1884, 14: 1863, 3: 1830, 17: 1830, 4: 1797, 11: 1773, 35: 1758, 36: 1752, 38: 1737, 22: 1695, 13: 1623})
#
# Jumlah kelas setelah SMOTE:
# Counter({0: 3570, 4: 3570, 9: 3570, 27: 3570, 18: 3570, 24: 3570, 23: 3570, 13: 3570, 20: 3570, 11: 3570, 16: 3570, 40: 3570, 28: 3570, 15: 3570, 21: 3570, 8: 3570, 31: 3570, 29: 3570, 5: 3570, 7: 3570, 41: 3570, 44: 3570, 3: 3570, 2: 3570, 14: 3570, 43: 3570, 36: 3570, 26: 3570, 34: 3570, 12: 3570, 37: 3570, 35: 3570, 42: 3570, 33: 3570, 17: 3570, 25: 3570, 6: 3570, 30: 3570, 39: 3570, 22: 3570, 10: 3570, 1: 3570, 19: 3570, 32: 3570, 38: 3570})

# %%
### split data 80% 20%

X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled,
                                                    test_size=0.2, random_state=42,
                                                    stratify=y_resampled)

# %%
from sklearn.preprocessing import StandardScaler

# Inisialisasi StandardScaler
scaler = StandardScaler()

# Fit scaler pada data training dan transform kedua set data
X_train_normalized = scaler.fit_transform(X_train)
X_test_normalized = scaler.transform(X_test)

# %%
pd.DataFrame(X_train_normalized)
# Out:
#               0         1         2         3         4         5         6   \
# 0      -0.125270 -0.462618 -0.063722  0.962710  0.546778 -0.530245 -0.215304
# 1      -0.447086 -0.164635 -0.081286  0.298297  0.031393 -0.255482  0.851859
# 2      -0.136721  0.693945 -0.652197  0.593003 -0.029296 -1.373536  0.804041
# 3      -1.041236  1.421366 -0.560796  0.131813 -0.337850 -0.264703  0.680879
# 4      -0.923043 -0.815273  0.428687  0.336918  0.459523  0.063171  0.295056
# ...          ...       ...       ...       ...       ...       ...       ...
# 128515 -1.069659  0.820296 -1.411504 -1.652472 -1.413538 -0.950462 -2.531171
# 128516  0.000360 -0.463296 -0.023205  0.176157 -0.034989 -0.226584  0.809894
# 128517 -2.370420  1.866536 -1.352947 -1.059491 -1.572022 -0.799900 -0.373726
# 128518  0.146890 -0.653630  0.677426  0.721152  0.754992  0.370645  0.048390
# 128519 -0.280134 -0.703109  0.021005  0.566020  0.206863 -0.449980 -0.051016
#
#               7         8         9   ...        16        17        18  \
# 0      -0.176643  1.412404  0.383635  ...  0.193716  0.060471  0.656303
# 1      -0.201491 -0.137365  0.157049  ... -1.101902 -1.626334  0.223691
# 2       0.107182  0.606830  0.598271  ... -0.054259 -1.238785 -1.046840
# 3      -0.053193  0.069079  0.717965  ... -1.921328  0.441973  0.176668
# 4      -0.775594 -1.244932 -2.012682  ...  0.224048  0.497766  0.512246
# ...          ...       ...       ...  ...       ...       ...       ...
# 128515  1.026397 -0.282676  2.174811  ... -1.828143  0.285871  0.049287
# 128516 -0.064593 -0.741426 -1.760898  ...  0.442690  0.649209 -0.596835
# 128517  1.257349  0.578946  0.872449  ...  0.865331 -0.488842  0.075970
# 128518 -0.953738  0.222994  0.610338  ... -0.512452 -1.230825  0.102356
# 128519 -0.075521  0.300568 -0.216127  ... -0.123118 -0.241533  0.031778
#
#               19        20        21        22        23        24        25
# 0      -0.022266  0.317852 -0.352507 -1.010202 -1.367641 -1.260068 -1.444051
# 1       0.817619 -1.296437 -0.614610 -0.134165 -3.339167 -0.671473  0.503199
# 2      -2.431179 -2.554992 -2.492506 -0.366025 -0.626432  0.076768  0.491064
# 3      -2.161943  0.177355  0.315965 -1.888467  0.640302  0.116856 -1.150069
# 4      -0.309098 -0.438342  0.097450  0.281906  0.694139  0.955619 -1.263811
# ...          ...       ...       ...       ...       ...       ...       ...
# 128515  0.720958  0.020781 -1.278091 -0.628007  0.212564 -1.642634 -2.222433
# 128516 -1.256466 -0.773914 -1.425531 -1.128419 -0.704997 -0.171163  0.474619
# 128517  0.050136 -1.373727  0.271099 -0.194054 -0.750243 -1.434839  0.372517
# 128518  0.297172 -0.461706 -1.169560 -0.183656  0.060295  0.011697  0.617881
# 128519  0.275208  1.477354  1.799078  2.096360  1.079606  0.597507  0.833435
#
# [128520 rows x 26 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
import pandas as pd

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
# Mendefinisikan model
dt = DecisionTreeClassifier(random_state=42)

# Mendefinisikan parameter grid
param_grid = {
    'max_depth': [3, 5, 7, 9, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2', None],
    'criterion': ['gini', 'entropy']
}

grid_search = GridSearchCV(
    dt, 
    param_grid, 
    cv=3, 
    n_jobs=1,  # Run sequentially
    verbose=1  # This will show progress
)


# Fit RandomizedSearchCV
grid_search.fit(X_train, y_train)

# Tampilkan parameter terbaik
print("Parameter terbaik:", grid_search.best_params_)
print("Skor terbaik:", grid_search.best_score_)

# Buat DataFrame dari hasil
results = pd.DataFrame(grid_search.cv_results_)

# Urutkan berdasarkan mean test score dari yang tertinggi ke terendah
results = results.sort_values('mean_test_score', ascending=False)

# Tampilkan kolom yang relevan
columns_to_display = ['params', 'mean_test_score', 'std_test_score', 'rank_test_score']
print(results[columns_to_display].to_string(index=False))

# Gunakan model terbaik untuk prediksi
best_knn = grid_search.best_estimator_
y_pred = best_knn.predict(X_test)

# Evaluasi model terbaik
print("Akurasi model terbaik:", accuracy_score(y_test, y_pred))
print("\nLaporan Klasifikasi:")
print(classification_report(y_test, y_pred))

# Simpan hasil ke CSV jika diperlukan
results[columns_to_display].to_csv('grid_search_results.csv', index=False)
# Out:
# Fitting 3 folds for each of 270 candidates, totalling 810 fits
# Parameter terbaik: {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Skor terbaik: 0.3630485527544351
#                                                                                                              params  mean_test_score  std_test_score  rank_test_score
#    {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2}         0.363049        0.000932                1
#       {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2}         0.355237        0.001643                2
#  {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}         0.345518        0.000667                3
#     {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}         0.343550        0.001955                4
#  {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}         0.342982        0.003355                5
#     {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}         0.340126        0.000708                6
#    {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2}         0.323000        0.000534                7
#    {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 5}         0.321732        0.001840                8
#       {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 5}         0.317390        0.001748                9
#    {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 5}         0.314838        0.002157               10
#       {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2}         0.313617        0.001924               11
#       {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 5}         0.308349        0.003405               12
#     {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}         0.297907        0.002168               13
#  {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}         0.295931        0.000749               14
#     {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}         0.293589        0.002190               15
#  {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}         0.292663        0.003402               16
#     {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}         0.292025        0.002367               17
#  {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}         0.289869        0.000781               18
#  {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}         0.289535        0.000810               19
#  {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}         0.288259        0.001636               20
#     {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}         0.286531        0.001983               21
#     {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}         0.285730        0.001900               22
#    {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2}         0.285131        0.001117               23
#    {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 5}         0.285131        0.001117               23
#     {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}         0.282571        0.001597               25
#      {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 10}         0.281349        0.003102               26
#      {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 10}         0.279614        0.002722               27
#  {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}         0.279209        0.003036               28
#   {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 10}         0.278968        0.000592               29
#       {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 5}         0.277638        0.002522               30
#       {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2}         0.277638        0.002522               30
#   {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 10}         0.277397        0.000573               32
#   {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 10}         0.275475        0.000238               33
#      {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 10}         0.269896        0.001539               34
#    {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}         0.261267        0.001876               35
#    {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}         0.257742        0.001546               36
#     {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}         0.256645        0.000198               37
#     {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}         0.256645        0.000198               37
#    {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}         0.254225        0.001886               39
#  {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}         0.253750        0.003523               40
#  {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}         0.253750        0.003523               40
#     {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}         0.250444        0.001622               42
#     {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}         0.250444        0.001622               42
#    {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}         0.250272        0.003516               44
#    {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}         0.248864        0.002411               45
#  {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}         0.248522        0.002306               46
#  {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}         0.248522        0.002306               46
# {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}         0.248125        0.003096               48
# {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}         0.246997        0.002535               49
# {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}         0.245067        0.000931               50
# {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}         0.243371        0.000592               51
# {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}         0.242538        0.003813               52
# {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}         0.242258        0.002212               53
#    {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}         0.241830        0.002738               54
#       {'criterion': 'entropy', 'max_depth': 9, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 5}         0.146359        0.002833               55
#       {'criterion': 'entropy', 'max_depth': 9, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2}         0.146359        0.002833               55
#      {'criterion': 'entropy', 'max_depth': 9, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 10}         0.146351        0.002843               57
#      {'criterion': 'entropy', 'max_depth': 9, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 10}         0.146351        0.002843               57
#      {'criterion': 'entropy', 'max_depth': 9, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 10}         0.146343        0.002834               59
#       {'criterion': 'entropy', 'max_depth': 9, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2}         0.146327        0.002813               60
#       {'criterion': 'entropy', 'max_depth': 9, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2}         0.146327        0.002813               60
#       {'criterion': 'entropy', 'max_depth': 9, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 5}         0.146320        0.002822               62
#       {'criterion': 'entropy', 'max_depth': 9, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 5}         0.146320        0.002822               62
#     {'criterion': 'entropy', 'max_depth': 9, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}         0.132003        0.001163               64
#     {'criterion': 'entropy', 'max_depth': 9, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}         0.132003        0.001163               64
#     {'criterion': 'entropy', 'max_depth': 9, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}         0.131769        0.001125               66
#     {'criterion': 'entropy', 'max_depth': 9, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}         0.131769        0.001125               66
#     {'criterion': 'entropy', 'max_depth': 9, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}         0.131769        0.001125               66
#     {'criterion': 'entropy', 'max_depth': 9, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}         0.131769        0.001125               66
#    {'criterion': 'entropy', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}         0.131178        0.003164               70
#    {'criterion': 'entropy', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}         0.131178        0.003164               70
#    {'criterion': 'entropy', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}         0.131170        0.003118               72
#    {'criterion': 'entropy', 'max_depth': 9, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}         0.130929        0.001660               73
#    {'criterion': 'entropy', 'max_depth': 9, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}         0.130929        0.001660               73
#    {'criterion': 'entropy', 'max_depth': 9, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}         0.130929        0.001660               73
#     {'criterion': 'entropy', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}         0.130462        0.002389               76
#     {'criterion': 'entropy', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}         0.130462        0.002389               76
#     {'criterion': 'entropy', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}         0.130377        0.002350               78
#     {'criterion': 'entropy', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}         0.130377        0.002350               78
#     {'criterion': 'entropy', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}         0.130377        0.002350               78
#     {'criterion': 'entropy', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}         0.130377        0.002350               78
#       {'criterion': 'gini', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}         0.119483        0.002982               82
#       {'criterion': 'gini', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}         0.119320        0.003209               83
#       {'criterion': 'entropy', 'max_depth': 7, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2}         0.119071        0.002880               84
#      {'criterion': 'entropy', 'max_depth': 7, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 10}         0.119071        0.002880               84
#       {'criterion': 'entropy', 'max_depth': 7, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 5}         0.119071        0.002880               84
#       {'criterion': 'entropy', 'max_depth': 7, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2}         0.119071        0.002880               84
#       {'criterion': 'entropy', 'max_depth': 7, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 5}         0.119071        0.002880               84
#      {'criterion': 'entropy', 'max_depth': 7, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 10}         0.119071        0.002880               84
#      {'criterion': 'entropy', 'max_depth': 7, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 10}         0.119071        0.002880               84
#       {'criterion': 'entropy', 'max_depth': 7, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 5}         0.119071        0.002880               84
#       {'criterion': 'entropy', 'max_depth': 7, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2}         0.119071        0.002880               84
#          {'criterion': 'gini', 'max_depth': 9, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2}         0.118534        0.001479               93
#          {'criterion': 'gini', 'max_depth': 9, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2}         0.118511        0.001324               94
#          {'criterion': 'gini', 'max_depth': 9, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 5}         0.118511        0.001324               94
#        {'criterion': 'gini', 'max_depth': 9, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}         0.118511        0.002180               96
#        {'criterion': 'gini', 'max_depth': 9, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}         0.118511        0.002180               96
#          {'criterion': 'gini', 'max_depth': 9, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 5}         0.118487        0.001375               98
#       {'criterion': 'gini', 'max_depth': 9, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}         0.118472        0.002724               99
#          {'criterion': 'gini', 'max_depth': 9, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 5}         0.118425        0.001350              100
#         {'criterion': 'gini', 'max_depth': 9, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 10}         0.118417        0.001386              101
#         {'criterion': 'gini', 'max_depth': 9, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 10}         0.118386        0.001327              102
#          {'criterion': 'gini', 'max_depth': 9, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2}         0.118378        0.001388              103
#         {'criterion': 'gini', 'max_depth': 9, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 10}         0.118378        0.001346              103
#        {'criterion': 'gini', 'max_depth': 9, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}         0.117647        0.001335              105
#        {'criterion': 'gini', 'max_depth': 9, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}         0.117383        0.000542              106
#        {'criterion': 'gini', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}         0.117305        0.001537              107
#        {'criterion': 'gini', 'max_depth': 9, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}         0.117079        0.000890              108
#       {'criterion': 'gini', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}         0.116542        0.003099              109
#        {'criterion': 'gini', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}         0.116410        0.001261              110
#        {'criterion': 'gini', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}         0.116138        0.002983              111
#       {'criterion': 'gini', 'max_depth': 9, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}         0.115663        0.003152              112
#        {'criterion': 'gini', 'max_depth': 9, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}         0.115212        0.000645              113
#       {'criterion': 'gini', 'max_depth': 9, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}         0.115188        0.002718              114
#        {'criterion': 'gini', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}         0.115126        0.002455              115
#        {'criterion': 'gini', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}         0.115126        0.002455              115
#        {'criterion': 'gini', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}         0.114325        0.001128              117
#     {'criterion': 'entropy', 'max_depth': 7, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}         0.106474        0.002625              118
#     {'criterion': 'entropy', 'max_depth': 7, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}         0.106474        0.002625              118
#    {'criterion': 'entropy', 'max_depth': 7, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}         0.106474        0.002625              118
#    {'criterion': 'entropy', 'max_depth': 7, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}         0.106474        0.002625              118
#     {'criterion': 'entropy', 'max_depth': 7, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}         0.106474        0.002625              118
#     {'criterion': 'entropy', 'max_depth': 7, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}         0.106474        0.002625              118
#     {'criterion': 'entropy', 'max_depth': 7, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}         0.106474        0.002625              118
#     {'criterion': 'entropy', 'max_depth': 7, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}         0.106474        0.002625              118
#    {'criterion': 'entropy', 'max_depth': 7, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}         0.106474        0.002625              118
#     {'criterion': 'entropy', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}         0.106474        0.001563              127
#     {'criterion': 'entropy', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}         0.106474        0.001563              127
#     {'criterion': 'entropy', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}         0.106474        0.001563              127
#     {'criterion': 'entropy', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}         0.106474        0.001563              127
#    {'criterion': 'entropy', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}         0.106474        0.001563              127
#    {'criterion': 'entropy', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}         0.106474        0.001563              127
#     {'criterion': 'entropy', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}         0.106474        0.001563              127
#     {'criterion': 'entropy', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}         0.106474        0.001563              127
#    {'criterion': 'entropy', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}         0.106474        0.001563              127
#        {'criterion': 'gini', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}         0.097113        0.001247              136
#        {'criterion': 'gini', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}         0.097106        0.001258              137
#        {'criterion': 'gini', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}         0.097035        0.001357              138
#        {'criterion': 'gini', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}         0.097035        0.001357              138
#        {'criterion': 'gini', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}         0.096732        0.001224              140
#        {'criterion': 'gini', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}         0.096732        0.001224              140
#       {'criterion': 'gini', 'max_depth': 7, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}         0.096522        0.004293              142
#       {'criterion': 'gini', 'max_depth': 7, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}         0.096491        0.004266              143
#       {'criterion': 'gini', 'max_depth': 7, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}         0.096429        0.004344              144
#       {'criterion': 'gini', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}         0.096250        0.001325              145
#       {'criterion': 'gini', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}         0.096250        0.001325              145
#       {'criterion': 'gini', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}         0.096242        0.001314              147
#        {'criterion': 'gini', 'max_depth': 7, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}         0.096211        0.004639              148
#        {'criterion': 'gini', 'max_depth': 7, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}         0.096211        0.004639              148
#         {'criterion': 'gini', 'max_depth': 7, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 10}         0.096078        0.000193              150
#          {'criterion': 'gini', 'max_depth': 7, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2}         0.096078        0.000206              150
#          {'criterion': 'gini', 'max_depth': 7, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2}         0.096071        0.000204              152
#          {'criterion': 'gini', 'max_depth': 7, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 5}         0.096071        0.000217              152
#          {'criterion': 'gini', 'max_depth': 7, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 5}         0.096063        0.000162              154
#          {'criterion': 'gini', 'max_depth': 7, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2}         0.096063        0.000162              154
#          {'criterion': 'gini', 'max_depth': 7, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 5}         0.096055        0.000212              156
#         {'criterion': 'gini', 'max_depth': 7, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 10}         0.096032        0.000210              157
#         {'criterion': 'gini', 'max_depth': 7, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 10}         0.096024        0.000210              158
#        {'criterion': 'gini', 'max_depth': 7, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}         0.093565        0.001341              159
#        {'criterion': 'gini', 'max_depth': 7, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}         0.093270        0.002009              160
#        {'criterion': 'gini', 'max_depth': 7, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}         0.093238        0.002053              161
#        {'criterion': 'gini', 'max_depth': 7, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}         0.093238        0.002053              161
#       {'criterion': 'entropy', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 5}         0.090375        0.001147              163
#       {'criterion': 'entropy', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2}         0.090375        0.001147              163
#      {'criterion': 'entropy', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 10}         0.090375        0.001147              163
#       {'criterion': 'entropy', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 5}         0.090375        0.001147              163
#       {'criterion': 'entropy', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 5}         0.090375        0.001147              163
#      {'criterion': 'entropy', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 10}         0.090375        0.001147              163
#       {'criterion': 'entropy', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2}         0.090375        0.001147              163
#      {'criterion': 'entropy', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 10}         0.090375        0.001147              163
#       {'criterion': 'entropy', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2}         0.090375        0.001147              163
#     {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}         0.076027        0.002087              172
#     {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}         0.076027        0.002087              172
#     {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}         0.076027        0.002087              172
#     {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}         0.076027        0.002087              172
#    {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}         0.076027        0.002087              172
#     {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}         0.076027        0.002087              172
#    {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}         0.076027        0.002087              172
#    {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}         0.076027        0.002087              172
#     {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}         0.076027        0.002087              172
#     {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}         0.075288        0.001451              181
#     {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}         0.075288        0.001451              181
#     {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}         0.075288        0.001451              181
#    {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}         0.075288        0.001451              181
#     {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}         0.075288        0.001451              181
#     {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}         0.075288        0.001451              181
#     {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}         0.075288        0.001451              181
#    {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}         0.075288        0.001451              181
#    {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}         0.075288        0.001451              181
#       {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}         0.072463        0.001088              190
#        {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}         0.072463        0.001088              190
#       {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}         0.072463        0.001088              190
#        {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}         0.072463        0.001088              190
#        {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}         0.072463        0.001088              190
#        {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}         0.072463        0.001088              190
#        {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}         0.072463        0.001088              190
#        {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}         0.072463        0.001088              190
#       {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}         0.072463        0.001088              190
#       {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}         0.072137        0.001652              199
#        {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}         0.072137        0.001652              199
#        {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}         0.072137        0.001652              199
#        {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}         0.072137        0.001652              199
#       {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}         0.072137        0.001652              199
#        {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}         0.072137        0.001652              199
#       {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}         0.072121        0.001668              205
#        {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}         0.072121        0.001668              205
#        {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}         0.072121        0.001668              205
#          {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 5}         0.071880        0.001526              208
#          {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2}         0.071880        0.001526              208
#         {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 10}         0.071880        0.001526              208
#          {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2}         0.071880        0.001526              208
#          {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 5}         0.071880        0.001526              208
#         {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 10}         0.071880        0.001526              208
#          {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 5}         0.071880        0.001526              208
#         {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 10}         0.071880        0.001526              208
#          {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2}         0.071880        0.001526              208
#       {'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2}         0.056871        0.001847              217
#       {'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2}         0.056871        0.001847              217
#      {'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 10}         0.056871        0.001847              217
#       {'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 5}         0.056871        0.001847              217
#       {'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2}         0.056871        0.001847              217
#      {'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 10}         0.056871        0.001847              217
#       {'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 5}         0.056871        0.001847              217
#      {'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 10}         0.056871        0.001847              217
#       {'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 5}         0.056871        0.001847              217
#    {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}         0.055104        0.000134              226
#     {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}         0.055104        0.000134              226
#     {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}         0.055104        0.000134              226
#    {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}         0.055104        0.000134              226
#    {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}         0.055104        0.000134              226
#     {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}         0.055104        0.000134              226
#     {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}         0.055104        0.000134              226
#     {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}         0.055104        0.000134              226
#     {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}         0.055104        0.000134              226
#       {'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}         0.053245        0.000403              235
#        {'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}         0.053245        0.000403              235
#       {'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}         0.053245        0.000403              235
#        {'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}         0.053245        0.000403              235
#       {'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}         0.053245        0.000403              235
#        {'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}         0.053245        0.000403              235
#        {'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}         0.053245        0.000403              235
#        {'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}         0.053245        0.000403              235
#        {'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}         0.053245        0.000403              235
#          {'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 5}         0.050941        0.002478              244
#         {'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 10}         0.050941        0.002478              244
#          {'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 5}         0.050941        0.002478              244
#          {'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2}         0.050941        0.002478              244
#         {'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 10}         0.050941        0.002478              244
#          {'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 5}         0.050941        0.002478              244
#          {'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2}         0.050941        0.002478              244
#          {'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2}         0.050941        0.002478              244
#         {'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 10}         0.050941        0.002478              244
#     {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2}         0.050070        0.001401              253
#    {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}         0.050070        0.001401              253
#    {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10}         0.050070        0.001401              253
#     {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}         0.050070        0.001401              253
#     {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}         0.050070        0.001401              253
#     {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2}         0.050070        0.001401              253
#    {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}         0.050070        0.001401              253
#     {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5}         0.050070        0.001401              253
#     {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}         0.050070        0.001401              253
#        {'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}         0.049603        0.000368              262
#        {'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5}         0.049603        0.000368              262
#        {'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}         0.049603        0.000368              262
#       {'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 10}         0.049603        0.000368              262
#       {'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10}         0.049603        0.000368              262
#        {'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5}         0.049603        0.000368              262
#        {'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 5}         0.049603        0.000368              262
#       {'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10}         0.049603        0.000368              262
#        {'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}         0.049603        0.000368              262
# Akurasi model terbaik: 0.437223778400249
#
# Laporan Klasifikasi:
#               precision    recall  f1-score   support
#
#            0       0.33      0.30      0.31       714
#            1       0.36      0.40      0.38       714
#            2       0.40      0.35      0.37       714
#            3       0.39      0.41      0.40       714
#            4       0.40      0.41      0.41       714
#            5       0.40      0.43      0.42       714
#            6       0.32      0.30      0.31       714
#            7       0.53      0.55      0.54       714
#            8       0.41      0.40      0.41       714
#            9       0.51      0.51      0.51       714
#           10       0.28      0.30      0.29       714
#           11       0.41      0.42      0.42       714
#           12       0.40      0.38      0.39       714
#           13       0.50      0.52      0.51       714
#           14       0.38      0.41      0.40       714
#           15       0.41      0.42      0.41       714
#           16       0.62      0.62      0.62       714
#           17       0.42      0.44      0.43       714
#           18       0.49      0.47      0.48       714
#           19       0.41      0.35      0.38       714
#           20       0.55      0.53      0.54       714
#           21       0.54      0.50      0.52       714
#           22       0.44      0.46      0.45       714
#           23       0.49      0.47      0.48       714
#           24       0.32      0.32      0.32       714
#           25       0.47      0.47      0.47       714
#           26       0.47      0.46      0.47       714
#           27       0.47      0.41      0.44       714
#           28       0.53      0.51      0.52       714
#           29       0.43      0.45      0.44       714
#           30       0.31      0.32      0.31       714
#           31       0.33      0.34      0.33       714
#           32       0.35      0.36      0.35       714
#           33       0.51      0.51      0.51       714
#           34       0.50      0.51      0.51       714
#           35       0.41      0.41      0.41       714
#           36       0.59      0.62      0.60       714
#           37       0.71      0.73      0.72       714
#           38       0.43      0.43      0.43       714
#           39       0.39      0.37      0.38       714
#           40       0.52      0.50      0.51       714
#           41       0.46      0.46      0.46       714
#           42       0.34      0.34      0.34       714
#           43       0.40      0.40      0.40       714
#           44       0.38      0.39      0.38       714
#
#     accuracy                           0.44     32130
#    macro avg       0.44      0.44      0.44     32130
# weighted avg       0.44      0.44      0.44     32130
